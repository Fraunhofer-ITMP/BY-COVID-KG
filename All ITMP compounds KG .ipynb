# %%
import pybel
import pandas as pd
from pybel.dsl import Protein
from pybel.dsl import Abundance
from pybel.dsl import Pathology
from pybel.dsl import BiologicalProcess
from pybel.dsl import Population
from pybel.dsl import Gene
from pybel.dsl import Rna
from pybel.dsl import MicroRna
from pybel.dsl import Fragment
import chembl_webresource_client
import openpyxl
import networkx as nx
from pybel.io.jupyter import to_jupyter
import matplotlib.pyplot as plt
import chembl_webresource_client
from chembl_webresource_client.new_client import new_client
import pubchempy
import pickle
import re

# %%
infile = open('data/normalized_data/itmp_chem_dis','rb')
drugIndList = pickle.load(infile)
infile.close()

# %%
infile = open('data/normalized_data/itmp_chem_moa','rb')
mechList = pickle.load(infile)
infile.close()

# %%
infile = open('data/normalized_data/itmp_chem_act_3','rb')
ActList = pickle.load(infile)
infile.close()

# %%
infile = open('data/normalized_data/chem2Gene','rb')
chem2GeneList = pickle.load(infile)
infile.close()

# %%
infile = open('data/normalized_data/Chem2Gene2Path','rb')
chem2Gene_all = pickle.load(infile)
infile.close()

# %%
chem2Gene_all
# Out:
# {'CHEMBL5694': [{'xref_id': 'R-HSA-110362',
#    'xref_name': 'POLB-Dependent Long Patch Base Excision Repair.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-162594',
#    'xref_name': 'Early Phase of HIV Life Cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-174414',
#    'xref_name': 'Processive synthesis on the C-strand of the telomere.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5358565',
#    'xref_name': 'Mismatch repair (MMR) directed by MSH2:MSH6 (MutSalpha).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5358606',
#    'xref_name': 'Mismatch repair (MMR) directed by MSH2:MSH3 (MutSbeta).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5651801',
#    'xref_name': 'PCNA-Dependent Long Patch Base Excision Repair.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5696397',
#    'xref_name': 'Gap-filling DNA repair synthesis and ligation in GG-NER.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6782210',
#    'xref_name': 'Gap-filling DNA repair synthesis and ligation in TC-NER.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69183',
#    'xref_name': 'Processive synthesis on the lagging strand.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'LIG1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1800': [{'xref_id': 'R-HSA-373080',
#    'xref_name': 'Class B/2 (Secretin family receptors).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418555',
#    'xref_name': 'G alpha (s) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9660821',
#    'xref_name': 'ADORA2B mediated anti-inflammatory cytokines production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CRHR1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2169716': [{'xref_id': 'R-HSA-3214841',
#    'xref_name': 'PKMTs methylate histone lysines.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804760',
#    'xref_name': 'Regulation of TP53 Activity through Methylation.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SMYD2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2508': [{'xref_id': 'R-HSA-2559580',
#    'xref_name': 'Oxidative Stress Induced Senescence.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2559582',
#    'xref_name': 'Senescence-Associated Secretory Phenotype (SASP).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2559585',
#    'xref_name': 'Oncogene Induced Senescence.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69231',
#    'xref_name': 'Cyclin D associated events in G1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8934593',
#    'xref_name': 'Regulation of RUNX1 Expression and Activity.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9630794',
#    'xref_name': 'Evasion of Oncogene Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9632700',
#    'xref_name': 'Evasion of Oxidative Stress Induced Senescence Due to Defective p16INK4A binding to CDK4 and CDK6.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9661069',
#    'xref_name': 'Defective binding of RB1 mutants to E2F1,(E2F2, E2F3).',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CDK6', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5314': [{'component_synonym': 'TYRO3', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1275212': [{'xref_id': 'R-HSA-5657562',
#    'xref_name': 'Essential fructosuria.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-70350',
#    'xref_name': 'Fructose catabolism.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'KHK', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5815': [{'xref_id': 'R-HSA-380108',
#    'xref_name': 'Chemokine receptors bind chemokines.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418594',
#    'xref_name': 'G alpha (i) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CCR9', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4093': [{'xref_id': 'R-HSA-1989781',
#    'xref_name': 'PPARA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-383280',
#    'xref_name': 'Nuclear Receptor transcription pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4090294',
#    'xref_name': 'SUMOylation of intracellular receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8866427',
#    'xref_name': 'VLDLR internalisation and degradation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029558',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression linked to lipogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029569',
#    'xref_name': 'NR1H3 & NR1H2 regulate gene expression linked to cholesterol transport and efflux.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9031525',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression to limit cholesterol uptake.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9031528',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression linked to triglyceride lipolysis in adipose.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9623433',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression to control bile acid homeostasis.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'NR1H2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3130': [{'xref_id': 'R-HSA-1257604',
#    'xref_name': 'PIP3 activates AKT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1660499',
#    'xref_name': 'Synthesis of PIPs at the plasma membrane.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2219530',
#    'xref_name': 'Constitutive Signaling by Aberrant PI3K in Cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-512988',
#    'xref_name': 'Interleukin-3, Interleukin-5 and GM-CSF signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811558',
#    'xref_name': 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853659',
#    'xref_name': 'RET signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9027276',
#    'xref_name': 'Erythropoietin activates Phosphoinositide-3-kinase (PI3K).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912526',
#    'xref_name': 'Interleukin receptor SHC signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912631',
#    'xref_name': 'Regulation of signaling by CBL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-983695',
#    'xref_name': 'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PIK3CD', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL279': [{'xref_id': 'R-HSA-194306',
#    'xref_name': 'Neurophilin interactions with VEGF and VEGFR.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-195399',
#    'xref_name': 'VEGF binds to VEGFR leading to receptor dimerization.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-216083',
#    'xref_name': 'Integrin cell surface interactions.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4420097',
#    'xref_name': 'VEGFA-VEGFR2 Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5218921',
#    'xref_name': 'VEGFR2 mediated cell proliferation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9673768',
#    'xref_name': 'Signaling by membrane-tethered fusions of PDGFRA or PDGFRB.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'KDR', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL227': [{'xref_id': 'R-HSA-375276',
#    'xref_name': 'Peptide ligand-binding receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416476',
#    'xref_name': 'G alpha (q) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8856825',
#    'xref_name': 'Cargo recognition for clathrin-mediated endocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8856828',
#    'xref_name': 'Clathrin-mediated endocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'AGTR1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1916': [{'xref_id': 'R-HSA-390696',
#    'xref_name': 'Adrenoceptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-392023',
#    'xref_name': 'Adrenaline signalling through Alpha-2 adrenergic receptor.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-400042',
#    'xref_name': 'Adrenaline,noradrenaline inhibits insulin secretion.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418594',
#    'xref_name': 'G alpha (i) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418597',
#    'xref_name': 'G alpha (z) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5683826',
#    'xref_name': 'Surfactant metabolism.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ADRA2C', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5872': [{'xref_id': 'R-HSA-375276',
#    'xref_name': 'Peptide ligand-binding receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418594',
#    'xref_name': 'G alpha (i) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'GPER1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1827': [{'xref_id': 'R-HSA-418457',
#    'xref_name': 'cGMP effects.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013422',
#    'xref_name': 'RHOBTB1 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PDE5A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1697668': [{'xref_id': 'R-HSA-159418',
#    'xref_name': 'Recycling of bile acids and salts.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-189483',
#    'xref_name': 'Heme degradation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5619110',
#    'xref_name': 'Defective SLCO1B1 causes hyperbilirubinemia, Rotor type (HBLRR).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-879518',
#    'xref_name': 'Transport of organic anions.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SLCO1B1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3784': [{'xref_id': 'R-HSA-1234158',
#    'xref_name': 'Regulation of gene expression by Hypoxia-inducible Factor.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1368082',
#    'xref_name': 'RORA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-156711',
#    'xref_name': 'Polo-like kinase mediated events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1912408',
#    'xref_name': 'Pre-NOTCH Transcription and Translation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1989781',
#    'xref_name': 'PPARA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-201722',
#    'xref_name': 'Formation of the beta-catenin:TCF transactivating complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-210744',
#    'xref_name': 'Regulation of gene expression in late stage (branching morphogenesis) pancreatic bud precursor cells.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2122947',
#    'xref_name': 'NOTCH1 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2197563',
#    'xref_name': 'NOTCH2 intracellular domain regulates transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2644606',
#    'xref_name': 'Constitutive Signaling by NOTCH1 PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2894862',
#    'xref_name': 'Constitutive Signaling by NOTCH1 HD+PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3134973',
#    'xref_name': 'LRR FLII-interacting protein 1 (LRRFIP1) activates type I IFN production.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3214847',
#    'xref_name': 'HATs acetylate histones.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3371568',
#    'xref_name': 'Attenuation phase.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-381340',
#    'xref_name': 'Transcriptional regulation of white adipocyte differentiation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3899300',
#    'xref_name': 'SUMOylation of transcription cofactors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-400253',
#    'xref_name': 'Circadian Clock.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5250924',
#    'xref_name': 'B-WICH complex positively regulates rRNA expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5617472',
#    'xref_name': 'Activation of anterior HOX genes in hindbrain development during early embryogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5621575',
#    'xref_name': 'CD209 (DC-SIGN) signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5689901',
#    'xref_name': 'Metalloprotease DUBs.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6781823',
#    'xref_name': 'Formation of TC-NER Pre-Incision Complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6781827',
#    'xref_name': 'Transcription-Coupled Nucleotide Excision Repair (TC-NER).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6782135',
#    'xref_name': 'Dual incision in TC-NER.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6782210',
#    'xref_name': 'Gap-filling DNA repair synthesis and ligation in TC-NER.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804114',
#    'xref_name': 'TP53 Regulates Transcription of Genes Involved in G2 Cell Cycle Arrest.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804758',
#    'xref_name': 'Regulation of TP53 Activity through Acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804760',
#    'xref_name': 'Regulation of TP53 Activity through Methylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811555',
#    'xref_name': 'PI5P Regulates TP53 Acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8866907',
#    'xref_name': 'Activation of the TFAP2 (AP-2) family of transcription factors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8936459',
#    'xref_name': 'RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8939243',
#    'xref_name': 'RUNX1 interacts with co-factors whose precise effect on RUNX1 targets is not known.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8941856',
#    'xref_name': 'RUNX3 regulates NOTCH signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8941858',
#    'xref_name': 'Regulation of RUNX3 expression and activity.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8951936',
#    'xref_name': 'RUNX3 regulates p14-ARF.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013508',
#    'xref_name': 'NOTCH3 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013695',
#    'xref_name': 'NOTCH4 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9018519',
#    'xref_name': 'Estrogen-dependent gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029569',
#    'xref_name': 'NR1H3 & NR1H2 regulate gene expression linked to cholesterol transport and efflux.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9031628',
#    'xref_name': 'NGF-stimulated transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-918233',
#    'xref_name': 'TRAF3-dependent IRF activation pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-933541',
#    'xref_name': 'TRAF6 mediated IRF7 activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9614657',
#    'xref_name': 'FOXO-mediated transcription of cell death genes.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9616222',
#    'xref_name': 'Transcriptional regulation of granulopoiesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9617629',
#    'xref_name': 'Regulation of FOXO transcriptional activity by acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9707616',
#    'xref_name': 'Heme signaling.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'EP300', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3514': [{'xref_id': 'R-HSA-422085',
#    'xref_name': 'Synthesis, secretion, and deacylation of Ghrelin.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PLA2G7', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3746': [{'xref_id': 'R-HSA-194002',
#    'xref_name': 'Glucocorticoid biosynthesis.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'HSD11B2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1917': [{'xref_id': 'R-HSA-375276',
#    'xref_name': 'Peptide ligand-binding receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418594',
#    'xref_name': 'G alpha (i) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SSTR1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL340': [{'xref_id': 'R-HSA-211981',
#    'xref_name': 'Xenobiotics.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5423646',
#    'xref_name': 'Aflatoxin activation and detoxification.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9027307',
#    'xref_name': 'Biosynthesis of maresin-like SPMs.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CYP3A4', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL222': [{'xref_id': 'R-HSA-442660',
#    'xref_name': 'Na+/Cl- dependent neurotransmitter transporters.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5619109',
#    'xref_name': 'Defective SLC6A2 causes orthostatic intolerance (OI).',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SLC6A2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2808': [{'xref_id': 'R-HSA-1989781',
#    'xref_name': 'PPARA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-383280',
#    'xref_name': 'Nuclear Receptor transcription pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4090294',
#    'xref_name': 'SUMOylation of intracellular receptors. [Q13133-1]',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8866427',
#    'xref_name': 'VLDLR internalisation and degradation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029558',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression linked to lipogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029569',
#    'xref_name': 'NR1H3 & NR1H2 regulate gene expression linked to cholesterol transport and efflux.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9031525',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression to limit cholesterol uptake.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9031528',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression linked to triglyceride lipolysis in adipose.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9623433',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression to control bile acid homeostasis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9632974',
#    'xref_name': 'NR1H2 & NR1H3 regulate gene expression linked to gluconeogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'NR1H3', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3572': [{'xref_id': 'R-HSA-8964041',
#    'xref_name': 'LDL remodeling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8964058',
#    'xref_name': 'HDL remodeling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029569',
#    'xref_name': 'NR1H3 & NR1H2 regulate gene expression linked to cholesterol transport and efflux.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CETP', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3867': [{'xref_id': 'R-HSA-71384',
#    'xref_name': 'Ethanol oxidation.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ADH7', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3959': [{'xref_id': 'R-HSA-211945',
#    'xref_name': 'Phase I - Functionalization of compounds.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'NQO2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3510': [{'xref_id': 'R-HSA-1475029',
#    'xref_name': 'Reversible hydration of carbon dioxide.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CA14', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4897': [{'xref_id': 'R-HSA-6804115',
#    'xref_name': 'TP53 regulates transcription of additional cell cycle genes whose exact role in the p53 pathway remain uncertain.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804756',
#    'xref_name': 'Regulation of TP53 Activity through Phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PLK3', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2758': [{'xref_id': 'R-HSA-4043916',
#    'xref_name': 'Defective MPI causes MPI-CDG (CDG-1b).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-446205',
#    'xref_name': 'Synthesis of GDP-mannose.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'MPI', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4305': [{'xref_id': 'R-HSA-1296052',
#    'xref_name': 'Ca2+ activated K+ channels.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'KCNN4', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2189110': [{'xref_id': 'R-HSA-212300',
#    'xref_name': 'PRC2 methylates histones and DNA.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2559580',
#    'xref_name': 'Oxidative Stress Induced Senescence.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3214841',
#    'xref_name': 'PKMTs methylate histone lysines.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5617472',
#    'xref_name': 'Activation of anterior HOX genes in hindbrain development during early embryogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8943724',
#    'xref_name': 'Regulation of PTEN gene transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8953750',
#    'xref_name': 'Transcriptional Regulation by E2F6.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9609690',
#    'xref_name': 'HCMV Early Events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9710421',
#    'xref_name': 'Defective pyroptosis.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'EZH2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL260': [{'xref_id': 'R-HSA-168638',
#    'xref_name': 'NOD1/2 Signaling Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-171007',
#    'xref_name': 'p38MAPK events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-198753',
#    'xref_name': 'ERK/MAPK targets.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2151209',
#    'xref_name': 'Activation of PPARGC1A (PGC-1alpha) by phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2559580',
#    'xref_name': 'Oxidative Stress Induced Senescence.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-376172',
#    'xref_name': 'DSCAM interactions.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418592',
#    'xref_name': 'ADP signalling through P2Y purinoceptor 1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-432142',
#    'xref_name': 'Platelet sensitization by LDL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4420097',
#    'xref_name': 'VEGFA-VEGFR2 Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-450302',
#    'xref_name': 'activated TAK1 mediates p38 MAPK activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-450341',
#    'xref_name': 'Activation of the AP-1 family of transcription factors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-450604',
#    'xref_name': 'KSRP (KHSRP) binds and destabilizes mRNA.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-525793',
#    'xref_name': 'Myogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5668599',
#    'xref_name': 'RHO GTPases Activate NADPH Oxidases.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6798695',
#    'xref_name': 'Neutrophil degranulation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804756',
#    'xref_name': 'Regulation of TP53 Activity through Phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9662834',
#    'xref_name': 'CD163 mediating an anti-inflammatory response.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'MAPK14', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1790': [{'xref_id': 'R-HSA-388479',
#    'xref_name': 'Vasopressin-like receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418555',
#    'xref_name': 'G alpha (s) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-432040',
#    'xref_name': 'Vasopressin regulates renal water homeostasis via Aquaporins.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8856825',
#    'xref_name': 'Cargo recognition for clathrin-mediated endocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8856828',
#    'xref_name': 'Clathrin-mediated endocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9036092',
#    'xref_name': 'Defective AVP does not bind AVPR2 and causes neurohypophyseal diabetes insipidus (NDI).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9660821',
#    'xref_name': 'ADORA2B mediated anti-inflammatory cytokines production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'AVPR2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3231': [{'xref_id': 'R-HSA-111465',
#    'xref_name': 'Apoptotic cleavage of cellular proteins.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3928662',
#    'xref_name': 'EPHB-mediated forward signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3928663',
#    'xref_name': 'EPHA-mediated growth cone collapse.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416482',
#    'xref_name': 'G alpha (12/13) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416572',
#    'xref_name': 'Sema4D induced cell migration and growth-cone collapse.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4420097',
#    'xref_name': 'VEGFA-VEGFR2 Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5627117',
#    'xref_name': 'RHO GTPases Activate ROCKs.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6798695',
#    'xref_name': 'Neutrophil degranulation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8980692',
#    'xref_name': 'RHOA GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013026',
#    'xref_name': 'RHOB GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013106',
#    'xref_name': 'RHOC GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013407',
#    'xref_name': 'RHOH GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013422',
#    'xref_name': 'RHOBTB1 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9679191',
#    'xref_name': 'Potential therapeutics for SARS.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9696264',
#    'xref_name': 'RND3 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ROCK1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3798': [{'xref_id': 'R-HSA-418555',
#    'xref_name': 'G alpha (s) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-419812',
#    'xref_name': 'Calcitonin-like ligand receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9660821',
#    'xref_name': 'ADORA2B mediated anti-inflammatory cytokines production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CALCRL', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3174': [{'xref_id': 'R-HSA-156581',
#    'xref_name': 'Methylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-156590',
#    'xref_name': 'Glutathione conjugation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-196836',
#    'xref_name': 'Vitamin C (ascorbate) metabolism.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8950505',
#    'xref_name': 'Gene and protein expression by JAK-STAT signaling after Interleukin-12 stimulation.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'GSTO1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3371': [{'xref_id': 'R-HSA-390666',
#    'xref_name': 'Serotonin receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418555',
#    'xref_name': 'G alpha (s) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9660821',
#    'xref_name': 'ADORA2B mediated anti-inflammatory cytokines production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'HTR6', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL251': [{'xref_id': 'R-HSA-187024',
#    'xref_name': 'NGF-independant TRKA activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-417973',
#    'xref_name': 'Adenosine P1 receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418555',
#    'xref_name': 'G alpha (s) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5683826',
#    'xref_name': 'Surfactant metabolism.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9660821',
#    'xref_name': 'ADORA2B mediated anti-inflammatory cytokines production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ADORA2A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5747': [{'xref_id': 'R-HSA-1234158',
#    'xref_name': 'Regulation of gene expression by Hypoxia-inducible Factor.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1368082',
#    'xref_name': 'RORA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1368108',
#    'xref_name': 'BMAL1:CLOCK,NPAS2 activates circadian gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1912408',
#    'xref_name': 'Pre-NOTCH Transcription and Translation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1989781',
#    'xref_name': 'PPARA activates gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-201722',
#    'xref_name': 'Formation of the beta-catenin:TCF transactivating complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-210744',
#    'xref_name': 'Regulation of gene expression in late stage (branching morphogenesis) pancreatic bud precursor cells.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2122947',
#    'xref_name': 'NOTCH1 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2151201',
#    'xref_name': 'Transcriptional activation of mitochondrial biogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2426168',
#    'xref_name': 'Activation of gene expression by SREBF (SREBP).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2644606',
#    'xref_name': 'Constitutive Signaling by NOTCH1 PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2894862',
#    'xref_name': 'Constitutive Signaling by NOTCH1 HD+PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3134973',
#    'xref_name': 'LRR FLII-interacting protein 1 (LRRFIP1) activates type I IFN production.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3214847',
#    'xref_name': 'HATs acetylate histones.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3371568',
#    'xref_name': 'Attenuation phase.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-350054',
#    'xref_name': 'Notch-HLH transcription pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-381340',
#    'xref_name': 'Transcriptional regulation of white adipocyte differentiation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3899300',
#    'xref_name': 'SUMOylation of transcription cofactors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-400206',
#    'xref_name': 'Regulation of lipid metabolism by PPARalpha.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-400253',
#    'xref_name': 'Circadian Clock.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5617472',
#    'xref_name': 'Activation of anterior HOX genes in hindbrain development during early embryogenesis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5621575',
#    'xref_name': 'CD209 (DC-SIGN) signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6803204',
#    'xref_name': 'TP53 Regulates Transcription of Genes Involved in Cytochrome C Release.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8866907',
#    'xref_name': 'Activation of the TFAP2 (AP-2) family of transcription factors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8939246',
#    'xref_name': 'RUNX1 regulates transcription of genes involved in differentiation of myeloid cells.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8941856',
#    'xref_name': 'RUNX3 regulates NOTCH signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013508',
#    'xref_name': 'NOTCH3 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013695',
#    'xref_name': 'NOTCH4 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9018519',
#    'xref_name': 'Estrogen-dependent gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-918233',
#    'xref_name': 'TRAF3-dependent IRF activation pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-933541',
#    'xref_name': 'TRAF6 mediated IRF7 activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9614657',
#    'xref_name': 'FOXO-mediated transcription of cell death genes.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9617629',
#    'xref_name': 'Regulation of FOXO transcriptional activity by acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9707564',
#    'xref_name': 'Cytoprotection by HMOX1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9707616',
#    'xref_name': 'Heme signaling.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CREBBP', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1741162': [{'xref_id': 'R-HSA-4043911',
#    'xref_name': 'Defective PMM2 causes PMM2-CDG (CDG-1a).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-446205',
#    'xref_name': 'Synthesis of GDP-mannose.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PMM2', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5896': [{'xref_id': 'R-HSA-3214842',
#    'xref_name': 'HDMs demethylate histones.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5693565',
#    'xref_name': 'Recruitment and ATM-mediated phosphorylation of repair and signaling proteins at DNA double strand breaks.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9029569',
#    'xref_name': 'NR1H3 & NR1H2 regulate gene expression linked to cholesterol transport and efflux.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'KDM4A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1903': [{'xref_id': 'R-HSA-442660',
#    'xref_name': 'Na+/Cl- dependent neurotransmitter transporters.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-888593',
#    'xref_name': 'Reuptake of GABA.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SLC6A1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4794': [{'xref_id': 'R-HSA-3295583',
#    'xref_name': 'TRP channels.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'TRPV1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2085': [{'xref_id': 'R-HSA-202733',
#    'xref_name': 'Cell surface interactions at the vascular wall.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6798695',
#    'xref_name': 'Neutrophil degranulation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8950505',
#    'xref_name': 'Gene and protein expression by JAK-STAT signaling after Interleukin-12 stimulation.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'MIF', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2553': [{'xref_id': 'R-HSA-198753',
#    'xref_name': 'ERK/MAPK targets.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-199920',
#    'xref_name': 'CREB phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2559582',
#    'xref_name': 'Senescence-Associated Secretory Phenotype (SASP).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-437239',
#    'xref_name': 'Recycling pathway of L1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-442742',
#    'xref_name': 'CREB1 phosphorylation through NMDA receptor-mediated activation of RAS signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-444257',
#    'xref_name': 'RSK activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-881907',
#    'xref_name': 'Gastrin-CREB signalling pathway via PKC and MAPK.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'RPS6KA1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2821': [{'xref_id': 'R-HSA-140837',
#    'xref_name': 'Intrinsic Pathway of Fibrin Clot Formation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9657688',
#    'xref_name': 'Defective factor XII causes hereditary angioedema.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9657689',
#    'xref_name': 'Defective SERPING1 causes hereditary angioedema.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'F12', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3629': [{'xref_id': 'R-HSA-1483191',
#    'xref_name': 'Synthesis of PC.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-201688',
#    'xref_name': 'WNT mediated activation of DVL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2514853',
#    'xref_name': 'Condensation of Prometaphase Chromosomes.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-445144',
#    'xref_name': 'Signal transduction by L1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804756',
#    'xref_name': 'Regulation of TP53 Activity through Phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6814122',
#    'xref_name': 'Cooperation of PDCL (PhLP1) and TRiC/CCT in G-protein beta folding.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8932339',
#    'xref_name': 'ROS sensing by NFE2L2.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8934903',
#    'xref_name': 'Receptor Mediated Mitophagy.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8939243',
#    'xref_name': 'RUNX1 interacts with co-factors whose precise effect on RUNX1 targets is not known.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8948751',
#    'xref_name': 'Regulation of PTEN stability and activity.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CSNK2A1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1942': [{'xref_id': 'R-HSA-390696',
#    'xref_name': 'Adrenoceptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-392023',
#    'xref_name': 'Adrenaline signalling through Alpha-2 adrenergic receptor.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418594',
#    'xref_name': 'G alpha (i) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-418597',
#    'xref_name': 'G alpha (z) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ADRA2B', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL5310': [{'xref_id': 'R-HSA-1181150',
#    'xref_name': 'Signaling by NODAL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1433617',
#    'xref_name': 'Regulation of signaling by NODAL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1502540',
#    'xref_name': 'Signaling by Activin.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ACVR1B', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4691': [{'xref_id': 'R-HSA-375276',
#    'xref_name': 'Peptide ligand-binding receptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416476',
#    'xref_name': 'G alpha (q) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-456926',
#    'xref_name': 'Thrombin signalling through proteinase activated receptors (PARs).',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'F2RL3', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3775': [{'xref_id': 'R-HSA-1362277',
#    'xref_name': 'Transcription of E2F targets under negative control by DREAM complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-156711',
#    'xref_name': 'Polo-like kinase mediated events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-176187',
#    'xref_name': 'Activation of ATR in response to replication stress.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5689880',
#    'xref_name': 'Ub-specific processing proteases.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69202',
#    'xref_name': 'Cyclin E associated events during G1/S transition.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69273',
#    'xref_name': 'Cyclin A/B1/B2 associated events during G2/M transition.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69601',
#    'xref_name': 'Ubiquitin Mediated Degradation of Phosphorylated Cdc25A.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69656',
#    'xref_name': 'Cyclin A:Cdk2-associated events at S phase entry.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8862803',
#    'xref_name': "Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models.",
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CDC25A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3535': [{'xref_id': 'R-HSA-418457',
#    'xref_name': 'cGMP effects.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PDE9A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2916': [{'xref_id': 'R-HSA-171319',
#    'xref_name': 'Telomere Extension By Telomerase.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-201722',
#    'xref_name': 'Formation of the beta-catenin:TCF transactivating complex.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'TERT', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3684': [{'xref_id': 'R-HSA-451308',
#    'xref_name': 'Activation of Ca-permeable Kainate Receptor.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-500657',
#    'xref_name': 'Presynaptic function of Kainate receptors.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'GRIK3', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1781': [{'xref_id': 'R-HSA-4615885',
#    'xref_name': 'SUMOylation of DNA replication proteins.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'TOP1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3145': [{'xref_id': 'R-HSA-109704',
#    'xref_name': 'PI3K Cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-112399',
#    'xref_name': 'IRS-mediated signalling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-114604',
#    'xref_name': 'GPVI-mediated activation cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1257604',
#    'xref_name': 'PIP3 activates AKT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1660499',
#    'xref_name': 'Synthesis of PIPs at the plasma membrane.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-186763',
#    'xref_name': 'Downstream signal transduction.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-198203',
#    'xref_name': 'PI3K/AKT activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-202424',
#    'xref_name': 'Downstream TCR signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2029485',
#    'xref_name': 'Role of phospholipids in phagocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-210993',
#    'xref_name': 'Tie2 Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2219530',
#    'xref_name': 'Constitutive Signaling by Aberrant PI3K in Cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2424491',
#    'xref_name': 'DAP12 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2730905',
#    'xref_name': 'Role of LAT2/NTAL/LAB on calcium mobilization.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-373753',
#    'xref_name': 'Nephrin family interactions.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4420097',
#    'xref_name': 'VEGFA-VEGFR2 Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-512988',
#    'xref_name': 'Interleukin-3, Interleukin-5 and GM-CSF signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5673001',
#    'xref_name': 'RAF/MAP kinase cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811558',
#    'xref_name': 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853659',
#    'xref_name': 'RET signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9027276',
#    'xref_name': 'Erythropoietin activates Phosphoinositide-3-kinase (PI3K).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912526',
#    'xref_name': 'Interleukin receptor SHC signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912631',
#    'xref_name': 'Regulation of signaling by CBL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9673767',
#    'xref_name': 'Signaling by PDGFRA transmembrane, juxtamembrane and kinase domain mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9673770',
#    'xref_name': 'Signaling by PDGFRA extracellular domain mutants.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PIK3CB', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL325': [{'xref_id': 'R-HSA-1362277',
#    'xref_name': 'Transcription of E2F targets under negative control by DREAM complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1362300',
#    'xref_name': 'Transcription of E2F targets under negative control by p107 (RBL1) and p130 (RBL2) in complex with HDAC1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1538133',
#    'xref_name': 'G0 and Early G1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-193670',
#    'xref_name': 'p75NTR negatively regulates cell cycle via SC1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-201722',
#    'xref_name': 'Formation of the beta-catenin:TCF transactivating complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2122947',
#    'xref_name': 'NOTCH1 Intracellular Domain Regulates Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2173795',
#    'xref_name': 'Downregulation of SMAD2/3:SMAD4 transcriptional activity.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2173796',
#    'xref_name': 'SMAD2/SMAD3:SMAD4 heterotrimer regulates transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2644606',
#    'xref_name': 'Constitutive Signaling by NOTCH1 PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2894862',
#    'xref_name': 'Constitutive Signaling by NOTCH1 HD+PEST Domain Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3214815',
#    'xref_name': 'HDACs deacetylate histones.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-350054',
#    'xref_name': 'Notch-HLH transcription pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3769402',
#    'xref_name': 'Deactivation of the beta-catenin transactivating complex.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-427389',
#    'xref_name': 'ERCC6 (CSB) and EHMT2 (G9a) positively regulate rRNA expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-427413',
#    'xref_name': 'NoRC negatively regulates rRNA expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4551638',
#    'xref_name': 'SUMOylation of chromatin organization proteins.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4641265',
#    'xref_name': 'Repression of WNT target genes.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804758',
#    'xref_name': 'Regulation of TP53 Activity through Acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69205',
#    'xref_name': 'G1/S-Specific Transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-73762',
#    'xref_name': 'RNA Polymerase I Transcription Initiation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8936459',
#    'xref_name': 'RUNX1 regulates genes involved in megakaryocyte differentiation and platelet function.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8943724',
#    'xref_name': 'Regulation of PTEN gene transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9018519',
#    'xref_name': 'Estrogen-dependent gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9022538',
#    'xref_name': 'Loss of MECP2 binding ability to 5mC-DNA.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9022692',
#    'xref_name': 'Regulation of MECP2 expression and activity.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9022699',
#    'xref_name': 'MECP2 regulates neuronal receptors and channels.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9022702',
#    'xref_name': 'MECP2 regulates transcription of neuronal ligands.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9615017',
#    'xref_name': 'FOXO-mediated transcription of oxidative stress, metabolic and neuronal genes.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9679191',
#    'xref_name': 'Potential therapeutics for SARS.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-983231',
#    'xref_name': 'Factors involved in megakaryocyte development and platelet production.',
#    'xref_src_db': 'Reactome'},
# ...
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6803207',
#    'xref_name': 'TP53 Regulates Transcription of Caspase Activators and Caspases.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6803211',
#    'xref_name': 'TP53 Regulates Transcription of Death Receptors and Ligands.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804114',
#    'xref_name': 'TP53 Regulates Transcription of Genes Involved in G2 Cell Cycle Arrest.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804115',
#    'xref_name': 'TP53 regulates transcription of additional cell cycle genes whose exact role in the p53 pathway remain uncertain.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804116',
#    'xref_name': 'TP53 Regulates Transcription of Genes Involved in G1 Cell Cycle Arrest.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804754',
#    'xref_name': 'Regulation of TP53 Expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804756',
#    'xref_name': 'Regulation of TP53 Activity through Phosphorylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804757',
#    'xref_name': 'Regulation of TP53 Degradation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804758',
#    'xref_name': 'Regulation of TP53 Activity through Acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804759',
#    'xref_name': 'Regulation of TP53 Activity through Association with Co-factors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6804760',
#    'xref_name': 'Regulation of TP53 Activity through Methylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811555',
#    'xref_name': 'PI5P Regulates TP53 Acetylation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69473',
#    'xref_name': 'G2/M DNA damage checkpoint.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69481',
#    'xref_name': 'G2/M Checkpoints.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69541',
#    'xref_name': 'Stabilization of p53.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69895',
#    'xref_name': 'Transcriptional activation of cell cycle inhibitor p21.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8852276',
#    'xref_name': 'The role of GTSE1 in G2/M progression after G2 checkpoint.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853884',
#    'xref_name': 'Transcriptional Regulation by VENTX.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8941855',
#    'xref_name': 'RUNX3 regulates CDKN1A transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8943724',
#    'xref_name': 'Regulation of PTEN gene transcription.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-983231',
#    'xref_name': 'Factors involved in megakaryocyte development and platelet production.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'TP53', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3559703': [{'xref_id': 'R-HSA-109704',
#    'xref_name': 'PI3K Cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-112399',
#    'xref_name': 'IRS-mediated signalling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-114604',
#    'xref_name': 'GPVI-mediated activation cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1236382',
#    'xref_name': 'Constitutive Signaling by Ligand-Responsive EGFR Cancer Variants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1250342',
#    'xref_name': 'PI3K events in ERBB4 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1257604',
#    'xref_name': 'PIP3 activates AKT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1266695',
#    'xref_name': 'Interleukin-7 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1433557',
#    'xref_name': 'Signaling by SCF-KIT.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1660499',
#    'xref_name': 'Synthesis of PIPs at the plasma membrane.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-180292',
#    'xref_name': 'GAB1 signalosome.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1839117',
#    'xref_name': 'Signaling by cytosolic FGFR1 fusion mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-186763',
#    'xref_name': 'Downstream signal transduction.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1963642',
#    'xref_name': 'PI3K events in ERBB2 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-198203',
#    'xref_name': 'PI3K/AKT activation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-202424',
#    'xref_name': 'Downstream TCR signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2029485',
#    'xref_name': 'Role of phospholipids in phagocytosis.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-210993',
#    'xref_name': 'Tie2 Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2219530',
#    'xref_name': 'Constitutive Signaling by Aberrant PI3K in Cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2424491',
#    'xref_name': 'DAP12 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2730905',
#    'xref_name': 'Role of LAT2/NTAL/LAB on calcium mobilization.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-373753',
#    'xref_name': 'Nephrin family interactions.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-388841',
#    'xref_name': 'Costimulation by the CD28 family.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-389357',
#    'xref_name': 'CD28 dependent PI3K/Akt signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416476',
#    'xref_name': 'G alpha (q) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-430116',
#    'xref_name': 'GP1b-IX-V activation signalling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-4420097',
#    'xref_name': 'VEGFA-VEGFR2 Pathway.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-512988',
#    'xref_name': 'Interleukin-3, Interleukin-5 and GM-CSF signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5637810',
#    'xref_name': 'Constitutive Signaling by EGFRvIII.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5654689',
#    'xref_name': 'PI-3K cascade:FGFR1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5654695',
#    'xref_name': 'PI-3K cascade:FGFR2.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5654710',
#    'xref_name': 'PI-3K cascade:FGFR3.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5654720',
#    'xref_name': 'PI-3K cascade:FGFR4.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5655253',
#    'xref_name': 'Signaling by FGFR2 in disease.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5655291',
#    'xref_name': 'Signaling by FGFR4 in disease.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5655302',
#    'xref_name': 'Signaling by FGFR1 in disease.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5673001',
#    'xref_name': 'RAF/MAP kinase cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6785807',
#    'xref_name': 'Interleukin-4 and Interleukin-13 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811558',
#    'xref_name': 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8851907',
#    'xref_name': 'MET activates PI3K/AKT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853334',
#    'xref_name': 'Signaling by FGFR3 fusions in cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853338',
#    'xref_name': 'Signaling by FGFR3 point mutants in cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853659',
#    'xref_name': 'RET signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8980692',
#    'xref_name': 'RHOA GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9009391',
#    'xref_name': 'Extra-nuclear estrogen signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013026',
#    'xref_name': 'RHOB GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013106',
#    'xref_name': 'RHOC GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013148',
#    'xref_name': 'CDC42 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013149',
#    'xref_name': 'RAC1 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013404',
#    'xref_name': 'RAC2 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013405',
#    'xref_name': 'RHOD GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013408',
#    'xref_name': 'RHOG GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013409',
#    'xref_name': 'RHOJ GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013420',
#    'xref_name': 'RHOU GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013423',
#    'xref_name': 'RAC3 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9013424',
#    'xref_name': 'RHOV GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9027276',
#    'xref_name': 'Erythropoietin activates Phosphoinositide-3-kinase (PI3K).',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9028335',
#    'xref_name': 'Activated NTRK2 signals through PI3K.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9035034',
#    'xref_name': 'RHOF GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912526',
#    'xref_name': 'Interleukin receptor SHC signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-912631',
#    'xref_name': 'Regulation of signaling by CBL.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9603381',
#    'xref_name': 'Activated NTRK3 signals through PI3K.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9607240',
#    'xref_name': 'FLT3 Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9664565',
#    'xref_name': 'Signaling by ERBB2 KD Mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9665348',
#    'xref_name': 'Signaling by ERBB2 ECD mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9670439',
#    'xref_name': 'Signaling by phosphorylated juxtamembrane, extracellular and kinase domain KIT mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9673767',
#    'xref_name': 'Signaling by PDGFRA transmembrane, juxtamembrane and kinase domain mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9673770',
#    'xref_name': 'Signaling by PDGFRA extracellular domain mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9696264',
#    'xref_name': 'RND3 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9696270',
#    'xref_name': 'RND2 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9696273',
#    'xref_name': 'RND1 GTPase cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9703465',
#    'xref_name': 'Signaling by FLT3 fusion proteins.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9703648',
#    'xref_name': 'Signaling by FLT3 ITD and TKD mutants.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-983695',
#    'xref_name': 'Antigen activates B Cell Receptor (BCR) leading to generation of second messengers.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PIK3R1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2331074': [{'xref_id': 'R-HSA-390696',
#    'xref_name': 'Adrenoceptors.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416476',
#    'xref_name': 'G alpha (q) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-416482',
#    'xref_name': 'G alpha (12/13) signalling events.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'ADRA1A', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1877': [{'component_synonym': 'embA', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2364678': [{'component_synonym': 'fabI', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL4306': [{'xref_id': 'R-HSA-1296072',
#    'xref_name': 'Voltage gated Potassium channels.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'KCNA5', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1641348': [{'xref_id': 'R-HSA-561048',
#    'xref_name': 'Organic anion transport.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'SLC22A8', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2095168': [{'xref_id': 'R-HSA-1237044',
#    'xref_name': 'Erythrocytes take up carbon dioxide and release oxygen.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1247673',
#    'xref_name': 'Erythrocytes take up oxygen and release carbon dioxide.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2168880',
#    'xref_name': 'Scavenging of heme from plasma.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9707564',
#    'xref_name': 'Cytoprotection by HMOX1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9707616',
#    'xref_name': 'Heme signaling.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'HBA1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL1938222': [{'xref_id': 'R-HSA-1660514',
#    'xref_name': 'Synthesis of PIPs at the Golgi membrane.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1660516',
#    'xref_name': 'Synthesis of PIPs at the early endosome membrane.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1660517',
#    'xref_name': 'Synthesis of PIPs at the late endosome membrane.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PIKFYVE', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL3610': [{'xref_id': 'R-HSA-187577',
#    'xref_name': 'SCF(Skp2)-mediated degradation of p27/p21.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-1912408',
#    'xref_name': 'Pre-NOTCH Transcription and Translation.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-3214858',
#    'xref_name': 'RMTs methylate histone arginines.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6785807',
#    'xref_name': 'Interleukin-4 and Interleukin-13 signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-69231',
#    'xref_name': 'Cyclin D associated events in G1.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-75815',
#    'xref_name': 'Ubiquitin-dependent degradation of Cyclin D.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8849470',
#    'xref_name': 'PTK6 Regulates Cell Cycle.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8853884',
#    'xref_name': 'Transcriptional Regulation by VENTX.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8878166',
#    'xref_name': 'Transcriptional regulation by RUNX2.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8934593',
#    'xref_name': 'Regulation of RUNX1 Expression and Activity.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8951430',
#    'xref_name': 'RUNX3 regulates WNT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-8951936',
#    'xref_name': 'RUNX3 regulates p14-ARF.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9018519',
#    'xref_name': 'Estrogen-dependent gene expression.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9634638',
#    'xref_name': 'Estrogen-dependent nuclear events downstream of ESR-membrane signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-9661069',
#    'xref_name': 'Defective binding of RB1 mutants to E2F1,(E2F2, E2F3).',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'CCND1', 'syn_type': 'GENE_SYMBOL'}],
#  'CHEMBL2095189': [{'xref_id': 'R-HSA-1257604',
#    'xref_name': 'PIP3 activates AKT signaling.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-186763',
#    'xref_name': 'Downstream signal transduction.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-186797',
#    'xref_name': 'Signaling by PDGF.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-2219530',
#    'xref_name': 'Constitutive Signaling by Aberrant PI3K in Cancer.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-5673001',
#    'xref_name': 'RAF/MAP kinase cascade.',
#    'xref_src_db': 'Reactome'},
#   {'xref_id': 'R-HSA-6811558',
#    'xref_name': 'PI5P, PP2A and IER3 Regulate PI3K/AKT Signaling.',
#    'xref_src_db': 'Reactome'},
#   {'component_synonym': 'PDGFRB', 'syn_type': 'GENE_SYMBOL'}],
#  ...}

# %%
infile = open('data/normalized_data/ActList2gene2Path','rb')
ActList2gene2Path = pickle.load(infile)
infile.close()

# %%
# %load Nmr2Graph.py
import pybel
import pandas as pd
from pybel.dsl import Protein
from pybel.dsl import Abundance
from pybel.dsl import Pathology
from pybel.dsl import BiologicalProcess
from pybel.dsl import Population
from pybel.dsl import Gene
from pybel.dsl import MicroRna
from pybel.dsl import Rna
from pybel.dsl import Fragment
import chembl_webresource_client
import openpyxl
import networkx as nx
from pybel.io.jupyter import to_jupyter
import matplotlib.pyplot as plt
import chembl_webresource_client
from chembl_webresource_client.new_client import new_client
import pubchempy
import pickle
import re

#function to retrieve mechanisms from ChEMBL

#nmrGraph = pybel.BELGraph(name='NMRgraph')
##nmrData = pd.read_csv('NMR_data_new.csv')
##nmr2chembl = pd.read_excel('Protein-Screening-Summary_CHEMBL30_Actives_teams_max08tan.xlsx')
#itmp_chem = pd.read_csv('C:\\Users\\reagon.karki\\Documents\\ITMP\\EOSC Future\\ITMP ChEMBL data\\CHEMBL4495564.csv',sep=';',usecols=['ChEMBL ID'])
##nmr2pchem = pd.read_excel('PubChem_Actives_Literature_NCATS.xlsx',sheet_name='Similar_065')

#Function to retrieve mechanism of actions and target proteins from ChEMBL
#Returns a dictionary
def RetMech(chemblIds):
    getMech = new_client.mechanism
    mechList = []
    for i in range(len(chemblIds)):
        mechs = getMech.filter(molecule_chembl_id=chemblIds[i]).only(['mechanism_of_action','target_chembl_id'])
        #mechs = getMech.filter(molecule_chembl_id=chemblIds[i])
        print(mechs)
        mechList.append(list(mechs))
    named_mechList = dict(zip(chemblIds,mechList))
    named_mechList = {k: v for k, v in named_mechList.items() if v}
    return(named_mechList)

#Function to retrieve associated diseases
#Returns a dictionary
def RetDrugInd(chemblIDs):
    getDrugInd = new_client.drug_indication
    drugIndList = []
    for i in range(len(chemblIDs)):
        drugInd = getDrugInd.filter(molecule_chembl_id=chemblIDs[i]).only('mesh_heading')
        #drugInd = getDrugInd.filter(molecule_chembl_id=chemblIDs[i])
        print(drugInd)
        drugIndList.append(list(drugInd))
    named_drugIndList = dict(zip(chemblIDs,drugIndList))
    named_drugIndList = {k: v for k, v in named_drugIndList.items() if v}
    return(named_drugIndList)

#Function to retrieve associated assays
#Returns a dictionary
def RetAct(chemblIds,j):
    GetAct = new_client.activity
    ActList = []
    #for i in range(len(chemblIds)):
    #print(chemblIds[0])
    for i in range(len(itmp_chem)):
        filtered_list=['assay_chembl_id','assay_type','pchembl_value','target_chembl_id','target_organism','bao_label']
        acts = GetAct.filter(molecule_chembl_id=chemblIds[i],pchembl_value__isnull=False,assay_type_iregex='(B|F)',target_organism='Homo sapiens').only(filtered_list)
        #acts = GetAct.filter(molecule_chembl_id=chemblIds[i],pchembl_value__isnull=False,target_organism='Homo sapiens').only(filtered_list)
        #acts = GetAct.filter(molecule_chembl_id=chemblIds[i],pchembl_value__isnull=False)
        j=j+1

        acts = [d for d in acts if d.get('target_organism') == 'Homo sapiens']
        acts = [d for d in acts if d.get('bao_label') == 'single protein format']
        acts = [d for d in acts if d.get('type') in ['Ki', 'IC50']]
        acts = [d for d in acts if float(d.get('pchembl_value')) >= 6]
        print(j)
        #print(len(acts))
        acts = acts[:5]
        print(acts)
        ActList.append(list(acts))
    #print(ActList)
    named_ActList = dict(zip(chemblIds,ActList))
    named_ActList = {k: v for k, v in named_ActList.items() if v}
    return(named_ActList)

def chembl2uniprot(chemblIDs, count):
    getTarget = new_client.target
    chem2Gene2path = []
    for i in range(len(chemblIDs)):
        print(count)
        count = count + 1
        chem2path = []
        chem = getTarget.filter(chembl_id=chemblIDs[i]).only('target_components')

        getGene = chem[0]['target_components'][0]['target_component_synonyms']
        getGene = [item for item in getGene if item["syn_type"] == "GENE_SYMBOL"][0]
        print(getGene)

        chem2path = [item for item in chem[0]['target_components'][0]['target_component_xrefs'] if
                     item["xref_src_db"] == "Reactome"]

        chem2path.append(getGene)
        chem2Gene2path.append(list(chem2path))

    named_chem2Gene2path = dict(zip(chemblIDs, chem2Gene2path))
    named_chem2Gene2path = {k: v for k, v in named_chem2Gene2path.items() if v}
    return (named_chem2Gene2path)

def chembl2gene2path(chem2geneList,ActList):
    for item in chem2geneList:
        #print(item)
        sizeOfitem = len(chem2geneList[item])
        #print(chem2Gene[item])
        #print(chem2geneList[item][sizeOfitem-1]['component_synonym'])
        gene = chem2geneList[item][sizeOfitem-1]['component_synonym']
        for jtem in ActList:
            #print(jtem,'b')
            #print(len(ActList_copy[jtem]))
            for i in range(len(ActList[jtem])):
                if item == ActList.get(jtem)[i]['target_chembl_id']:
                #print(jtem)
                    newkey = {'Protein': gene}
                    ActList[jtem][i].update(newkey)
                #print(ActList_copy.get(jtem)[i]['target_chembl_id'])

    return(ActList)


def filter_graph(mainGraph, vprotList):
    nsp_list = []
    for u, v, data in mainGraph.edges(data=True):
        if u.name in vprotList or v.name in vprotList:
            nsp_list.append(u)
            nsp_list.append(v)

    for u, v, data in mainGraph.edges(data=True):
        if 'Similarity' not in data:
            continue
        if data['Similarity'] >= .65 and (u in nsp_list or v in nsp_list):
            # yield u, v, k, data
            nsp_list.append(u)
            nsp_list.append(v)

    # print(nsp_list)

    nsp_graph = mainGraph.subgraph(nsp_list)
    # return(to_jupyter(nsp_graph))
    final_nsp = [node for node in nsp_graph.nodes() if isinstance(node, pybel.dsl.Protein) and node.name in vprotList]
    # print(final_nsp)
    for u, v, data in nsp_graph.edges(data=True):
        if u.namespace in ['Enamine', 'ChEMBL', 'CID'] and v.namespace in ['Enamine', 'ChEMBL', 'CID']:
            final_nsp.append(u)
            final_nsp.append(v)

    # return(nsp_graph.subgraph(final_nsp))
    nsp_graph = nsp_graph.subgraph(final_nsp)
    # chembl_act = []
    nsp_nodes = [node for node in nsp_graph.nodes()]
    for u in nsp_graph.nodes():
        if u.namespace == 'ChEMBL':
            # test = nmrGraph.neighbors(u)
            chem = [n for n in mainGraph.neighbors(u)]
            nsp_nodes.extend(chem)

    return (mainGraph.subgraph(nsp_nodes))


#Functions for creating graph
def chem2moa_rel(named_mechList,itmpGraph):
    for i in named_mechList:
    #print(i)
    #break
    #print(named_mechList[i])
    #print(len(named_mechList[i]))
    #break
        for j in range(len(named_mechList[i])):
            #print(named_mechList[i][j]['mechanism_of_action'])
            #print(named_mechList[i][j]['target_chembl_id'])
            #print(i)
            #break
            itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),BiologicalProcess(namespace='MOA',name=named_mechList[i][j]['mechanism_of_action']),citation='ChEMBL database',evidence='ChEMBL query')
            if not named_mechList[i][j]['target_chembl_id'] == None:
                itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),MicroRna(namespace='HP',name=named_mechList[i][j]['Protein']),citation='ChEMBL database',evidence='ChEMBL query')
    return(itmpGraph)

def chem2dis_rel(named_drugIndList,itmpGraph):
    for i in named_drugIndList:
    #print(i)
    #break
    #print(named_drugIndList[i])
    #print(len(named_drugIndList[i]))
    #break
        for j in range(len(named_drugIndList[i])):
            #print(named_drugIndList[i][j]['mesh_heading'])
            #print(i)
            #break
            itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),Population(namespace='Disease',name=named_drugIndList[i][j]['mesh_heading']),citation='ChEMBL database',evidence='ChEMBL query')
    return(itmpGraph)

def chem2act_rel(named_ActList,itmpGraph):
    for i in named_ActList:
        for j in range(len(named_ActList[i])):
            # print(named_mechList[i][j]['mechanism_of_action'])
            # print(named_mechList[i][j]['target_chembl_id'])
            # print(i)
            # break
            # nmrGraph.add_association(Pathology(namespace='ChEMBL',name=i),BiologicalProcess(namespace='MOA',name=mechList[i][j]['mechanism_of_action']),citation='ChEMBL database',evidence='ChEMBL query')
            if not named_ActList[i][j]['target_chembl_id'] == None:
                itmpGraph.add_association(Abundance(namespace='ChEMBLAssay',name=named_ActList[i][j]['assay_chembl_id']),
                                         MicroRna(namespace='HP', name=named_ActList[i][j]['ProteinName']),
                                         citation='ChEMBL database', evidence='ChEMBL query')

            itmpGraph.add_association(Pathology(namespace='ChEMBL', name=i),Abundance(namespace='ChEMBLAssay',name=named_ActList[i][j]['assay_chembl_id']),
                                      citation='ChEMBL database', evidence='ChEMBL query',assayType=named_ActList[i][j]['assay_type'],
                                      pChEMBL=named_ActList[i][j]['pchembl_value'])

    return(itmpGraph)


def chem2act_rel_2(named_ActList, itmpGraph):
    for i in named_ActList:
        # print(i)
        for j in range(len(named_ActList[i])):
            if not named_ActList[i][j]['target_chembl_id'] == None:
                if 'Protein' in named_ActList[i][j]:
                    itmpGraph.add_association(
                        Abundance(namespace='ChEMBLAssay', name=named_ActList[i][j]['assay_chembl_id']),
                        MicroRna(namespace='HP', name=named_ActList[i][j]['Protein']),
                        citation='ChEMBL database', evidence='ChEMBL query')
                else:
                    itmpGraph.add_association(
                        Abundance(namespace='ChEMBLAssay', name=named_ActList[i][j]['assay_chembl_id']),
                        MicroRna(namespace='HP', name=named_ActList[i][j]['target_chembl_id']),
                        citation='ChEMBL database', evidence='ChEMBL query')

            itmpGraph.add_association(Pathology(namespace='ChEMBL', name=i),
                                      Abundance(namespace='ChEMBLAssay', name=named_ActList[i][j]['assay_chembl_id']),
                                      citation='ChEMBL database', evidence='ChEMBL query',
                                      assayType=named_ActList[i][j]['assay_type'],
                                      pChEMBL=named_ActList[i][j]['pchembl_value'])

    return (itmpGraph)

def chem2gene2path_rel(named_chem2geneList,itmpGraph):
    for item in named_chem2geneList:
        itemLen = len(named_chem2geneList[item])-1
        for j in range(itemLen):
            #print(named_chem2geneList)
            itmpGraph.add_association(MicroRna(namespace='HP', name=named_chem2geneList[item][itemLen]['component_synonym']),
                                      Rna(namespace='Pathway',name=named_chem2geneList[item][j]['xref_name']),
                                      citation='ChEMBL database', evidence='ChEMBL query',
                                      Reactome=named_chem2geneList[item][j]['xref_id'])

    return(itmpGraph)


def chembl2uniprot(chemblIDs, count):
    getTarget = new_client.target
    chem2Gene2path = []
    chemHasNoPath = []
    chemNotprotein = []
    for i in range(len(chemblIDs)):
        # print(count)
        count = count + 1
        chem2path = []
        chem = getTarget.filter(chembl_id=chemblIDs[i]).only('target_components')
        # print(chem)
        # break
        try:
            uprot_id = chem[0]['target_components'][0]['accession']
        except IndexError:
            # print(chemblIDs[i])
            chemHasNoPath.append(chemblIDs[i])
            continue

        if chem[0]['target_components'][0]['accession'] == None:
            chemHasNoPath.append(chemblIDs[i])
            # continue

    chemblIDs_clean = [item for item in chemblIDs if item not in chemHasNoPath]
    print('old', len(chemblIDs_clean))
    for i in range(len(chemblIDs_clean)):

        chem = getTarget.filter(chembl_id=chemblIDs_clean[i]).only('target_components')
        # print(chem)
        # break
        getGene = chem[0]['target_components'][0]['target_component_synonyms']
        # rint(getGene)
        # break
        try:
            getGene = [item for item in getGene if item["syn_type"] == "GENE_SYMBOL"][0]
        except IndexError:
            chemNotprotein.append(chemblIDs_clean[i])
            continue
    chemblIDs_clean = [item for item in chemblIDs_clean if item not in chemNotprotein]
    print('newLen', len(chemblIDs_clean))
    print(len(chemNotprotein))
    # break
    # print(getGene)
    # break
    for i in range(len(chemblIDs_clean)):
        chem = getTarget.filter(chembl_id=chemblIDs_clean[i]).only('target_components')
        # print(chem)
        # break
        getGene = chem[0]['target_components'][0]['target_component_synonyms']
        getGene = [item for item in getGene if item["syn_type"] == "GENE_SYMBOL"][0]

        chem2path = [item for item in chem[0]['target_components'][0]['target_component_xrefs'] if
                     item["xref_src_db"] == "Reactome"]

        chem2path.append(getGene)
        print(chem2path)
        # break
        chem2Gene2path.append(chem2path)
        # print(chem2Gene2path)
        # break

        # print(chem2Gene2path)

    # print(chemHasNoPath)
    named_chem2Gene2path = dict(zip(chemblIDs_clean, chem2Gene2path))
    named_chem2Gene2path = {k: v for k, v in named_chem2Gene2path.items() if v}
    return (named_chem2Gene2path)

# %%
def chem2act_rel_2(named_ActList,itmpGraph):
    for i in named_ActList:
        #print(i)
        for j in range(len(named_ActList[i])):
            # print(named_mechList[i][j]['mechanism_of_action'])
            # print(named_mechList[i][j]['target_chembl_id'])
            # print(i)
            # break
            # nmrGraph.add_association(Pathology(namespace='ChEMBL',name=i),BiologicalProcess(namespace='MOA',name=mechList[i][j]['mechanism_of_action']),citation='ChEMBL database',evidence='ChEMBL query')
            if not named_ActList[i][j]['target_chembl_id'] == None:
                if 'Protein' in named_ActList[i][j]:
                    itmpGraph.add_association(Abundance(namespace='ChEMBLAssay',name=named_ActList[i][j]['assay_chembl_id']),
                                         MicroRna(namespace='HP', name=named_ActList[i][j]['ProteinName']),
                                         citation='ChEMBL database', evidence='ChEMBL query')
                else:
                    itmpGraph.add_association(Abundance(namespace='ChEMBLAssay',name=named_ActList[i][j]['assay_chembl_id']),
                                         MicroRna(namespace='HP', name=named_ActList[i][j]['target_chembl_id']),
                                         citation='ChEMBL database', evidence='ChEMBL query')
                    

            itmpGraph.add_association(Pathology(namespace='ChEMBL', name=i),Abundance(namespace='ChEMBLAssay',name=named_ActList[i][j]['assay_chembl_id']),
                                      citation='ChEMBL database', evidence='ChEMBL query',assayType=named_ActList[i][j]['assay_type'],
                                      pChEMBL=named_ActList[i][j]['pchembl_value'])

    return(itmpGraph)

# %%
itmp_Graph = pybel.BELGraph(name='itmpGraph')

# %%
from Nmr2Graph import chembl2gene2path
ActList2gene2Path_3 = chembl2gene2path(chem2Gene_all,ActList)

# %%
ActList2gene2Path_3
# Out:
# {'CHEMBL56731': [{'assay_chembl_id': 'CHEMBL763200',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.16',
#    'target_chembl_id': 'CHEMBL203',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.7',
#    'Protein': 'EGFR'}],
#  'CHEMBL1076347': [{'assay_chembl_id': 'CHEMBL1819920',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.89',
#    'target_chembl_id': 'CHEMBL2409',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '13.0',
#    'Protein': 'EPHX2'}],
#  'CHEMBL332898': [{'assay_chembl_id': 'CHEMBL760831',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.30',
#    'target_chembl_id': 'CHEMBL1827',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.5',
#    'Protein': 'PDE5A'},
#   {'assay_chembl_id': 'CHEMBL4398715',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.22',
#    'target_chembl_id': 'CHEMBL1827',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.6',
#    'Protein': 'PDE5A'}],
#  'CHEMBL445332': [{'assay_chembl_id': 'CHEMBL839506',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.72',
#    'target_chembl_id': 'CHEMBL237',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '1.9',
#    'Protein': 'OPRK1'},
#   {'assay_chembl_id': 'CHEMBL839506',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.42',
#    'target_chembl_id': 'CHEMBL237',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '38.0',
#    'Protein': 'OPRK1'},
#   {'assay_chembl_id': 'CHEMBL968095',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.72',
#    'target_chembl_id': 'CHEMBL237',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '1.9',
#    'Protein': 'OPRK1'},
#   {'assay_chembl_id': 'CHEMBL1168405',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.72',
#    'target_chembl_id': 'CHEMBL237',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '1.9',
#    'Protein': 'OPRK1'},
#   {'assay_chembl_id': 'CHEMBL1775888',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.13',
#    'target_chembl_id': 'CHEMBL237',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '7.4',
#    'Protein': 'OPRK1'}],
#  'CHEMBL427526': [{'assay_chembl_id': 'CHEMBL1052371',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.30',
#    'target_chembl_id': 'CHEMBL2157',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '50.0',
#    'Protein': 'CXCL8'}],
#  'CHEMBL430893': [{'assay_chembl_id': 'CHEMBL855486',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.64',
#    'target_chembl_id': 'CHEMBL275',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '231.0',
#    'Protein': 'PDE4B'},
#   {'assay_chembl_id': 'CHEMBL855487',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.79',
#    'target_chembl_id': 'CHEMBL254',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '162.0',
#    'Protein': 'PDE4A'},
#   {'assay_chembl_id': 'CHEMBL855489',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.21',
#    'target_chembl_id': 'CHEMBL288',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '622.0',
#    'Protein': 'PDE4D'},
#   {'assay_chembl_id': 'CHEMBL1953791',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.30',
#    'target_chembl_id': 'CHEMBL275',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.5',
#    'Protein': 'PDE4B'},
#   {'assay_chembl_id': 'CHEMBL2161156',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.26',
#    'target_chembl_id': 'CHEMBL254',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.55',
#    'Protein': 'PDE4A'}],
#  'CHEMBL267014': [{'assay_chembl_id': 'CHEMBL674046',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.40',
#    'target_chembl_id': 'CHEMBL219',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.4',
#    'Protein': 'DRD4'},
#   {'assay_chembl_id': 'CHEMBL672347',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.35',
#    'target_chembl_id': 'CHEMBL217',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '448.0',
#    'Protein': 'DRD2'},
#   {'assay_chembl_id': 'CHEMBL675946',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.37',
#    'target_chembl_id': 'CHEMBL219',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.43',
#    'Protein': 'DRD4'},
#   {'assay_chembl_id': 'CHEMBL847755',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.89',
#    'target_chembl_id': 'CHEMBL287',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '130.0',
#    'Protein': 'SIGMAR1'},
#   {'assay_chembl_id': 'CHEMBL671702',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.22',
#    'target_chembl_id': 'CHEMBL219',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.6',
#    'Protein': 'DRD4'}],
#  'CHEMBL266240': [{'assay_chembl_id': 'CHEMBL657039',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.41',
#    'target_chembl_id': 'CHEMBL3594',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '39.0',
#    'Protein': 'CA9'},
#   {'assay_chembl_id': 'CHEMBL824220',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.12',
#    'target_chembl_id': 'CHEMBL205',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '75.0',
#    'Protein': 'CA2'},
#   {'assay_chembl_id': 'CHEMBL824221',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.80',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '160.0',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL657150',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.12',
#    'target_chembl_id': 'CHEMBL205',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '75.0',
#    'Protein': 'CA2'},
#   {'assay_chembl_id': 'CHEMBL657967',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.41',
#    'target_chembl_id': 'CHEMBL3594',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '39.0',
#    'Protein': 'CA9'}],
#  'CHEMBL1401670': [{'assay_chembl_id': 'CHEMBL2148639',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.54',
#    'target_chembl_id': 'CHEMBL1293292',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.29',
#    'Protein': 'KCNJ1'}],
#  'CHEMBL284969': [{'assay_chembl_id': 'CHEMBL640526',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.77',
#    'target_chembl_id': 'CHEMBL251',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '17.0',
#    'Protein': 'ADORA2A'},
#   {'assay_chembl_id': 'CHEMBL643030',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.19',
#    'target_chembl_id': 'CHEMBL226',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '6.4',
#    'Protein': 'ADORA1'},
#   {'assay_chembl_id': 'CHEMBL642231',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.19',
#    'target_chembl_id': 'CHEMBL251',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '639.0',
#    'Protein': 'ADORA2A'},
#   {'assay_chembl_id': 'CHEMBL641972',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.55',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '281.0',
#    'Protein': 'ADORA3'},
#   {'assay_chembl_id': 'CHEMBL875922',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.94',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '114.0',
#    'Protein': 'ADORA3'}],
#  'CHEMBL3903492': [{'assay_chembl_id': 'CHEMBL3854862',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.16',
#    'target_chembl_id': 'CHEMBL2850',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '691.0',
#    'Protein': 'GSK3A'}],
#  'CHEMBL81379': [{'assay_chembl_id': 'CHEMBL4700552',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.72',
#    'target_chembl_id': 'CHEMBL6152',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.19',
#    'Protein': 'SNCA'},
#   {'assay_chembl_id': 'CHEMBL4700570',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.75',
#    'target_chembl_id': 'CHEMBL2487',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.18',
#    'Protein': 'APP'}],
#  'CHEMBL2019024': [{'assay_chembl_id': 'CHEMBL2020670',
#    'assay_type': 'A',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.70',
#    'target_chembl_id': 'CHEMBL3622',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.02',
#    'Protein': 'CYP2C19'}],
#  'CHEMBL393929': [{'assay_chembl_id': 'CHEMBL892530',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.47',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.34',
#    'Protein': 'CDK2'},
#   {'assay_chembl_id': 'CHEMBL892529',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.46',
#    'target_chembl_id': 'CHEMBL308',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.035',
#    'Protein': 'CDK1'},
#   {'assay_chembl_id': 'CHEMBL892535',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.50',
#    'target_chembl_id': 'CHEMBL2996',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.32',
#    'Protein': 'PRKCD'},
#   {'assay_chembl_id': 'CHEMBL2013813',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.72',
#    'target_chembl_id': 'CHEMBL308',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.019',
#    'Protein': 'CDK1'}],
#  'CHEMBL384073': [{'assay_chembl_id': 'CHEMBL3811365',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.00',
#    'target_chembl_id': 'CHEMBL3231',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.1',
#    'Protein': 'ROCK1'},
#   {'assay_chembl_id': 'CHEMBL4043633',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.11',
#    'target_chembl_id': 'CHEMBL4079',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.77',
#    'Protein': 'GRK2'}],
#  'CHEMBL108335': [{'assay_chembl_id': 'CHEMBL685171',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.75',
#    'target_chembl_id': 'CHEMBL4616',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '18.0',
#    'Protein': 'GHSR'}],
#  'CHEMBL3908979': [{'assay_chembl_id': 'CHEMBL4339977',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.72',
#    'target_chembl_id': 'CHEMBL3973',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '1.9',
#    'Protein': 'FGFR4'}],
#  'CHEMBL515414': [{'assay_chembl_id': 'CHEMBL1062882',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.12',
#    'target_chembl_id': 'CHEMBL2068',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.76',
#    'Protein': 'EPHA2'},
#   {'assay_chembl_id': 'CHEMBL1062889',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.02',
#    'target_chembl_id': 'CHEMBL4501',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.95',
#    'Protein': 'RPS6KB1'},
#   {'assay_chembl_id': 'CHEMBL1061196',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.29',
#    'target_chembl_id': 'CHEMBL2073',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.51',
#    'Protein': 'YES1'},
#   {'assay_chembl_id': 'CHEMBL1777645',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.82',
#    'target_chembl_id': 'CHEMBL2345',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '15.0',
#    'Protein': 'RPS6KA3'}],
#  'CHEMBL3672369': [{'assay_chembl_id': 'CHEMBL3705860',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.50',
#    'target_chembl_id': 'CHEMBL5855',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '32.0',
#    'Protein': 'NEK1'},
#   {'assay_chembl_id': 'CHEMBL4384180',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.45',
#    'target_chembl_id': 'CHEMBL4896',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '353.7',
#    'Protein': 'PBK'}],
#  'CHEMBL129677': [{'assay_chembl_id': 'CHEMBL814457',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.47',
#    'target_chembl_id': 'CHEMBL4439',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.034',
#    'Protein': 'TGFBR1'},
#   {'assay_chembl_id': 'CHEMBL732623',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.11',
#    'target_chembl_id': 'CHEMBL260',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.078',
#    'Protein': 'MAPK14'}],
#  'CHEMBL273019': [{'assay_chembl_id': 'CHEMBL4046839',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.68',
#    'target_chembl_id': 'CHEMBL1795129',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.208',
#    'Protein': 'IL6'}],
#  'CHEMBL3797437': [{'assay_chembl_id': 'CHEMBL3804643',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.44',
#    'target_chembl_id': 'CHEMBL2085',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.36',
#    'Protein': 'MIF'}],
#  'CHEMBL284861': [{'assay_chembl_id': 'CHEMBL4151662',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.16',
#    'target_chembl_id': 'CHEMBL262',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.69',
#    'Protein': 'GSK3B'}],
#  'CHEMBL1771212': [{'assay_chembl_id': 'CHEMBL1771912',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.77',
#    'target_chembl_id': 'CHEMBL4588',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '1.7',
#    'Protein': 'MMP8'},
#   {'assay_chembl_id': 'CHEMBL1771913',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.70',
#    'target_chembl_id': 'CHEMBL321',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.2',
#    'Protein': 'MMP9'},
#   {'assay_chembl_id': 'CHEMBL1771915',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.85',
#    'target_chembl_id': 'CHEMBL3869',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '14.0',
#    'Protein': 'MMP14'},
#   {'assay_chembl_id': 'CHEMBL1771910',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.54',
#    'target_chembl_id': 'CHEMBL283',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '29.0',
#    'Protein': 'MMP3'},
#   {'assay_chembl_id': 'CHEMBL1806090',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.89',
#    'target_chembl_id': 'CHEMBL3869',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '13.0',
#    'Protein': 'MMP14'}],
#  'CHEMBL341324': [{'assay_chembl_id': 'CHEMBL615223',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.28',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '52.0',
#    'Protein': 'HSD11B1'},
#   {'assay_chembl_id': 'CHEMBL977261',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.28',
#    'target_chembl_id': 'CHEMBL3181',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '52.0',
#    'Protein': 'HSD17B1'},
#   {'assay_chembl_id': 'CHEMBL977263',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.55',
#    'target_chembl_id': 'CHEMBL2789',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '284.0',
#    'Protein': 'HSD17B2'},
#   {'assay_chembl_id': 'CHEMBL2155280',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.28',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '52.0',
#    'Protein': 'HSD11B1'},
#   {'assay_chembl_id': 'CHEMBL3294007',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.28',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '52.0',
#    'Protein': 'HSD11B1'}],
#  'CHEMBL2179319': [{'assay_chembl_id': 'CHEMBL3858878',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.82',
#    'target_chembl_id': 'CHEMBL5137',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '15.0',
#    'Protein': 'GRM2'}],
#  'CHEMBL8486': [{'assay_chembl_id': 'CHEMBL654079',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.96',
#    'target_chembl_id': 'CHEMBL3891',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '11.0',
#    'Protein': 'CAPN1'},
#   {'assay_chembl_id': 'CHEMBL884249',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.96',
#    'target_chembl_id': 'CHEMBL3891',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '11.0',
#    'Protein': 'CAPN1'}],
#  'CHEMBL255408': [{'assay_chembl_id': 'CHEMBL832760',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.75',
#    'target_chembl_id': 'CHEMBL4015',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.18',
#    'Protein': 'CCR2'}],
#  'CHEMBL399530': [{'assay_chembl_id': 'CHEMBL832973',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.55',
#    'target_chembl_id': 'CHEMBL3880',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.28',
#    'Protein': 'HSP90AA1'}],
#  'CHEMBL31354': [{'assay_chembl_id': 'CHEMBL1776961',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.80',
#    'target_chembl_id': 'CHEMBL219',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '16.0',
#    'Protein': 'DRD4'},
#   {'assay_chembl_id': 'CHEMBL1776962',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.49',
#    'target_chembl_id': 'CHEMBL232',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '322.0',
#    'Protein': 'ADRA1B'},
#   {'assay_chembl_id': 'CHEMBL1776964',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.70',
#    'target_chembl_id': 'CHEMBL229',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '20.0',
#    'Protein': 'ADRA1A'},
#   {'assay_chembl_id': 'CHEMBL1776966',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.62',
#    'target_chembl_id': 'CHEMBL1898',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '24.0',
#    'Protein': 'HTR1B'},
#   {'assay_chembl_id': 'CHEMBL1776965',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.66',
#    'target_chembl_id': 'CHEMBL214',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '2.2',
#    'Protein': 'HTR1A'}],
#  'CHEMBL258805': [{'assay_chembl_id': 'CHEMBL660704',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.96',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.11',
#    'Protein': 'CDK2'},
#   {'assay_chembl_id': 'CHEMBL676766',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.89',
#    'target_chembl_id': 'CHEMBL279',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.13',
#    'Protein': 'KDR'},
#   {'assay_chembl_id': 'CHEMBL1250278',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.19',
#    'target_chembl_id': 'CHEMBL4036',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.065',
#    'Protein': 'CDK5'},
#   {'assay_chembl_id': 'CHEMBL1250276',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.52',
#    'target_chembl_id': 'CHEMBL331',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.3',
#    'Protein': 'CDK4'},
#   {'assay_chembl_id': 'CHEMBL1250281',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.46',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.035',
#    'Protein': 'CDK2'}],
#  'CHEMBL72365': [{'assay_chembl_id': 'CHEMBL3363743',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.36',
#    'target_chembl_id': 'CHEMBL1906',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '4.4',
#    'Protein': 'RAF1'},
#   {'assay_chembl_id': 'CHEMBL3363741',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.27',
#    'target_chembl_id': 'CHEMBL5145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '5.4',
#    'Protein': 'BRAF'},
#   {'assay_chembl_id': 'CHEMBL3363740',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.97',
#    'target_chembl_id': 'CHEMBL5145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '10.71',
#    'Protein': 'BRAF'},
#   {'assay_chembl_id': 'CHEMBL4262904',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.82',
#    'target_chembl_id': 'CHEMBL5145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.0015',
#    'Protein': 'BRAF'},
#   {'assay_chembl_id': 'CHEMBL4328310',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.84',
#    'target_chembl_id': 'CHEMBL1169596',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '1.46',
#    'Protein': 'ARAF'}],
#  'CHEMBL1230640': [{'assay_chembl_id': 'CHEMBL3110468',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.22',
#    'target_chembl_id': 'CHEMBL6175',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.6',
#    'Protein': 'KDM4C'},
#   {'assay_chembl_id': 'CHEMBL3112253',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.52',
#    'target_chembl_id': 'CHEMBL1293226',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.3',
#    'Protein': 'KDM4E'},
#   {'assay_chembl_id': 'CHEMBL3110469',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.77',
#    'target_chembl_id': 'CHEMBL1938209',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.17',
#    'Protein': 'KDM3A'},
#   {'assay_chembl_id': 'CHEMBL3112251',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.85',
#    'target_chembl_id': 'CHEMBL1938211',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.14',
#    'Protein': 'KDM6B'}],
#  'CHEMBL419667': [{'assay_chembl_id': 'CHEMBL1017392',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.70',
#    'target_chembl_id': 'CHEMBL1889',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.002',
#    'Protein': 'AVPR1A'}],
#  'CHEMBL417727': [{'assay_chembl_id': 'CHEMBL655779',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.40',
#    'target_chembl_id': 'CHEMBL3243',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.4',
#    'Protein': 'PTPRC'},
#   {'assay_chembl_id': 'CHEMBL663367',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.22',
#    'target_chembl_id': 'CHEMBL3837',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.6',
#    'Protein': 'CTSL'}],
#  'CHEMBL348890': [{'assay_chembl_id': 'CHEMBL4343396',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.14',
#    'target_chembl_id': 'CHEMBL3155',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '7.24',
#    'Protein': 'HTR7'},
#   {'assay_chembl_id': 'CHEMBL4343397',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.50',
#    'target_chembl_id': 'CHEMBL214',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '316.0',
#    'Protein': 'HTR1A'}],
#  'CHEMBL4065323': [{'assay_chembl_id': 'CHEMBL3998326',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.40',
#    'target_chembl_id': 'CHEMBL4142',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '4.0',
#    'Protein': 'FGFR2'},
#   {'assay_chembl_id': 'CHEMBL3998352',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.03',
#    'target_chembl_id': 'CHEMBL2742',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '93.0',
#    'Protein': 'FGFR3'},
#   {'assay_chembl_id': 'CHEMBL3998353',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.50',
#    'target_chembl_id': 'CHEMBL3973',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '32.0',
#    'Protein': 'FGFR4'},
#   {'assay_chembl_id': 'CHEMBL3998359',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.00',
#    'target_chembl_id': 'CHEMBL3650',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '1.0',
#    'Protein': 'FGFR1'}],
#  'CHEMBL19612': [{'assay_chembl_id': 'CHEMBL1217097',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.95',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.112',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL1217105',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.00',
#    'target_chembl_id': 'CHEMBL3510',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '1.0',
#    'Protein': 'CA14'}],
#  'CHEMBL405759': [{'assay_chembl_id': 'CHEMBL1249829',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.52',
#    'target_chembl_id': 'CHEMBL262',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.03',
#    'Protein': 'GSK3B'},
#   {'assay_chembl_id': 'CHEMBL4602766',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.52',
#    'target_chembl_id': 'CHEMBL262',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '30.0',
#    'Protein': 'GSK3B'},
#   {'assay_chembl_id': 'CHEMBL4733696',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.52',
#    'target_chembl_id': 'CHEMBL262',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '30.0',
#    'Protein': 'GSK3B'}],
#  'CHEMBL1231568': [{'assay_chembl_id': 'CHEMBL2217198',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.05',
#    'target_chembl_id': 'CHEMBL3959',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.9',
#    'Protein': 'NQO2'},
#   {'assay_chembl_id': 'CHEMBL2217199',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.10',
#    'target_chembl_id': 'CHEMBL3959',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.8',
#    'Protein': 'NQO2'}],
#  'CHEMBL3629569': [{'assay_chembl_id': 'CHEMBL3756249',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.42',
#    'target_chembl_id': 'CHEMBL4685',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '38.0',
#    'Protein': 'IDO1'},
#   {'assay_chembl_id': 'CHEMBL3800855',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.55',
#    'target_chembl_id': 'CHEMBL4685',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '28.0',
#    'Protein': 'IDO1'},
#   {'assay_chembl_id': 'CHEMBL4194376',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.14',
#    'target_chembl_id': 'CHEMBL4685',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '7.2',
#    'Protein': 'IDO1'},
#   {'assay_chembl_id': 'CHEMBL4262613',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.15',
#    'target_chembl_id': 'CHEMBL4685',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '7.0',
#    'Protein': 'IDO1'},
#   {'assay_chembl_id': 'CHEMBL4367261',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.22',
#    'target_chembl_id': 'CHEMBL4685',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.06',
#    'Protein': 'IDO1'}],
#  'CHEMBL10347': [{'assay_chembl_id': 'CHEMBL643573',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.46',
#    'target_chembl_id': 'CHEMBL223',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '3.5',
#    'Protein': 'ADRA1D'},
#   {'assay_chembl_id': 'CHEMBL651996',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.34',
#    'target_chembl_id': 'CHEMBL232',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '4.6',
#    'Protein': 'ADRA1B'},
#   {'assay_chembl_id': 'CHEMBL648098',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.22',
#    'target_chembl_id': 'CHEMBL232',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.6',
#    'Protein': 'ADRA1B'}],
#  'CHEMBL2170062': [{'assay_chembl_id': 'CHEMBL2173623',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.48',
#    'target_chembl_id': 'CHEMBL1833',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '328.0',
#    'Protein': 'HTR2B'},
#   {'assay_chembl_id': 'CHEMBL4775659',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.77',
#    'target_chembl_id': 'CHEMBL287',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '17.0',
#    'Protein': 'SIGMAR1'}],
#  'CHEMBL364005': [{'assay_chembl_id': 'CHEMBL880618',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.13',
#    'target_chembl_id': 'CHEMBL3371',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '7.4',
#    'Protein': 'HTR6'},
#   {'assay_chembl_id': 'CHEMBL880615',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.96',
#    'target_chembl_id': 'CHEMBL1898',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '110.0',
#    'Protein': 'HTR1B'},
#   {'assay_chembl_id': 'CHEMBL881486',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.62',
#    'target_chembl_id': 'CHEMBL224',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '240.0',
#    'Protein': 'HTR2A'},
#   {'assay_chembl_id': 'CHEMBL881487',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.35',
#    'target_chembl_id': 'CHEMBL225',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '450.0',
#    'Protein': 'HTR2C'}],
#  'CHEMBL2385591': [{'assay_chembl_id': 'CHEMBL2390520',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.16',
#    'target_chembl_id': 'CHEMBL5467',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '695.0',
#    'Protein': 'BMPR2'},
#   {'assay_chembl_id': 'CHEMBL2390525',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.27',
#    'target_chembl_id': 'CHEMBL5275',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '539.0',
#    'Protein': 'BMPR1A'},
#   {'assay_chembl_id': 'CHEMBL2390518',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.49',
#    'target_chembl_id': 'CHEMBL4267',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '327.0',
#    'Protein': 'TGFBR2'},
#   {'assay_chembl_id': 'CHEMBL2390522',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.03',
#    'target_chembl_id': 'CHEMBL5476',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '92.9',
#    'Protein': 'BMPR1B'},
#   {'assay_chembl_id': 'CHEMBL2390524',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.58',
#    'target_chembl_id': 'CHEMBL5903',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '26.2',
#    'Protein': 'ACVR1'}],
#  'CHEMBL2169920': [{'assay_chembl_id': 'CHEMBL3420707',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.92',
#    'target_chembl_id': 'CHEMBL2169716',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.12',
#    'Protein': 'SMYD2'},
#   {'assay_chembl_id': 'CHEMBL3592282',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.64',
#    'target_chembl_id': 'CHEMBL2169716',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.23',
#    'Protein': 'SMYD2'}],
#  'CHEMBL209148': [{'assay_chembl_id': 'CHEMBL864159',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.72',
#    'target_chembl_id': 'CHEMBL2959',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '19.0',
#    'Protein': 'ITK'},
#   {'assay_chembl_id': 'CHEMBL1249995',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.80',
#    'target_chembl_id': 'CHEMBL2959',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '16.0',
#    'Protein': 'ITK'}],
#  'CHEMBL1337170': [{'assay_chembl_id': 'CHEMBL4481809',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.37',
#    'target_chembl_id': 'CHEMBL4261',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '43.0',
#    'Protein': 'HIF1A'}],
#  'CHEMBL68738': [{'assay_chembl_id': 'CHEMBL875922',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.85',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '142.0',
#    'Protein': 'ADORA3'},
#   {'assay_chembl_id': 'CHEMBL646634',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.21',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '615.0',
#    'Protein': 'ADORA3'},
#   {'assay_chembl_id': 'CHEMBL646635',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.86',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '137.0',
#    'Protein': 'ADORA3'},
#   {'assay_chembl_id': 'CHEMBL3772106',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.23',
#    'target_chembl_id': 'CHEMBL226',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '5.9',
#    'Protein': 'ADORA1'},
#   {'assay_chembl_id': 'CHEMBL3777321',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.14',
#    'target_chembl_id': 'CHEMBL256',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '72.0',
#    'Protein': 'ADORA3'}],
#  'CHEMBL355001': [{'assay_chembl_id': 'CHEMBL827387',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.00088',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL839572',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.00088',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL1023848',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.00088',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL1118583',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '880.0',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL1645696',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '10.15',
#    'target_chembl_id': 'CHEMBL3025',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.07',
#    'Protein': 'CA6'}],
#  'CHEMBL3913746': [{'assay_chembl_id': 'CHEMBL3861252',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.12',
#    'target_chembl_id': 'CHEMBL1075165',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.076',
#    'Protein': 'PIK3C3'},
#   {'assay_chembl_id': 'CHEMBL4308983',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.60',
#    'target_chembl_id': 'CHEMBL1075165',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '25.0',
#    'Protein': 'PIK3C3'}],
#  'CHEMBL399121': [{'assay_chembl_id': 'CHEMBL1225718',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.29',
#    'target_chembl_id': 'CHEMBL4878',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '511.0',
#    'Protein': 'CYP1B1'},
#   {'assay_chembl_id': 'CHEMBL3631190',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.99',
#    'target_chembl_id': 'CHEMBL3729',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '102.1',
#    'Protein': 'CA4'},
#   {'assay_chembl_id': 'CHEMBL3631191',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.48',
#    'target_chembl_id': 'CHEMBL2326',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '3.3',
#    'Protein': 'CA7'},
#   {'assay_chembl_id': 'CHEMBL3631192',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.34',
#    'target_chembl_id': 'CHEMBL3242',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '454.1',
#    'Protein': 'CA12'},
#   {'assay_chembl_id': 'CHEMBL4232373',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.55',
#    'target_chembl_id': 'CHEMBL284',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.28',
#    'Protein': 'DPP4'}],
#  'CHEMBL180672': [{'assay_chembl_id': 'CHEMBL832717',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.71',
#    'target_chembl_id': 'CHEMBL240',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '194.0',
#    'Protein': 'KCNH2'},
#   {'assay_chembl_id': 'CHEMBL828597',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.37',
#    'target_chembl_id': 'CHEMBL1878',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.043',
#    'Protein': 'CASR'},
#   {'assay_chembl_id': 'CHEMBL1055309',
#    'assay_type': 'A',
#    'bao_label': 'single protein format',
#    'pchembl_value': '10.35',
#    'target_chembl_id': 'CHEMBL289',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.045',
#    'Protein': 'CYP2D6'},
#   {'assay_chembl_id': 'CHEMBL1055307',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.70',
#    'target_chembl_id': 'CHEMBL222',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.2',
#    'Protein': 'SLC6A2'},
#   {'assay_chembl_id': 'CHEMBL1055308',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.70',
#    'target_chembl_id': 'CHEMBL238',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.2',
#    'Protein': 'SLC6A3'}],
#  'CHEMBL37537': [{'assay_chembl_id': 'CHEMBL1670882',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.33',
#    'target_chembl_id': 'CHEMBL205',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.47',
#    'Protein': 'CA2'},
#   {'assay_chembl_id': 'CHEMBL2340799',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.16',
#    'target_chembl_id': 'CHEMBL3510',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.69',
#    'Protein': 'CA14'}],
#  'CHEMBL256777': [{'assay_chembl_id': 'CHEMBL934813',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.11',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '7.8',
#    'Protein': 'HSD11B1'},
#   {'assay_chembl_id': 'CHEMBL995584',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.11',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '7.8',
#    'Protein': 'HSD11B1'},
#   {'assay_chembl_id': 'CHEMBL2405913',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.12',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '7.5',
#    'Protein': 'HSD11B1'},
#   {'assay_chembl_id': 'CHEMBL3294007',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.10',
#    'target_chembl_id': 'CHEMBL4235',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '8.0',
#    'Protein': 'HSD11B1'}],
#  'CHEMBL363160': [{'assay_chembl_id': 'CHEMBL827045',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.57',
#    'target_chembl_id': 'CHEMBL4722',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.027',
#    'Protein': 'AURKA'},
#   {'assay_chembl_id': 'CHEMBL831066',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.87',
#    'target_chembl_id': 'CHEMBL2185',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '135.0',
#    'Protein': 'AURKB'},
#   {'assay_chembl_id': 'CHEMBL831067',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.92',
#    'target_chembl_id': 'CHEMBL3935',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '120.0',
#    'Protein': 'AURKC'},
#   {'assay_chembl_id': 'CHEMBL827046',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.87',
#    'target_chembl_id': 'CHEMBL2185',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '135.0',
#    'Protein': 'AURKB'},
#   {'assay_chembl_id': 'CHEMBL827047',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.92',
#    'target_chembl_id': 'CHEMBL3935',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '120.0',
#    'Protein': 'AURKC'}],
#  'CHEMBL2048872': [{'assay_chembl_id': 'CHEMBL2049740',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.30',
#    'target_chembl_id': 'CHEMBL4523',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.005',
#    'Protein': 'PIM2'},
#   {'assay_chembl_id': 'CHEMBL2049743',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.82',
#    'target_chembl_id': 'CHEMBL4523',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.15',
#    'Protein': 'PIM2'},
#   {'assay_chembl_id': 'CHEMBL2049744',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.05',
#    'target_chembl_id': 'CHEMBL5407',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.009',
#    'Protein': 'PIM3'},
#   {'assay_chembl_id': 'CHEMBL3106176',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.64',
#    'target_chembl_id': 'CHEMBL5407',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.23',
#    'Protein': 'PIM3'},
#   {'assay_chembl_id': 'CHEMBL3106178',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.80',
#    'target_chembl_id': 'CHEMBL4523',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.16',
#    'Protein': 'PIM2'}],
#  'CHEMBL51697': [{'assay_chembl_id': 'CHEMBL2211271',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.03',
#    'target_chembl_id': 'CHEMBL228',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '935.0',
#    'Protein': 'SLC6A4'},
#   {'assay_chembl_id': 'CHEMBL2211272',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.37',
#    'target_chembl_id': 'CHEMBL238',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '43.0',
#    'Protein': 'SLC6A3'},
#   {'assay_chembl_id': 'CHEMBL2211273',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.67',
#    'target_chembl_id': 'CHEMBL222',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '21.5',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL366254': [{'assay_chembl_id': 'CHEMBL3224722',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.43',
#    'target_chembl_id': 'CHEMBL2382',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.37',
#    'Protein': 'CAPN2'}],
#  'CHEMBL3770936': [{'assay_chembl_id': 'CHEMBL3771929',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.82',
#    'target_chembl_id': 'CHEMBL1865',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.015',
#    'Protein': 'HDAC6'}],
#  'CHEMBL86313': [{'assay_chembl_id': 'CHEMBL880848',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.30',
#    'target_chembl_id': 'CHEMBL2015',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '5.0',
#    'Protein': 'GRIN1'}],
#  'CHEMBL2137199': [{'assay_chembl_id': 'CHEMBL3227569',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.98',
#    'target_chembl_id': 'CHEMBL1741186',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '105.0',
#    'Protein': 'RORC'},
#   {'assay_chembl_id': 'CHEMBL3368933',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.98',
#    'target_chembl_id': 'CHEMBL1741186',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '105.0',
#    'Protein': 'RORC'}],
#  'CHEMBL188381': [{'assay_chembl_id': 'CHEMBL828488',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.70',
#    'target_chembl_id': 'CHEMBL279',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '2.0',
#    'Protein': 'KDR'}],
#  'CHEMBL456237': [{'assay_chembl_id': 'CHEMBL948494',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.00',
#    'target_chembl_id': 'CHEMBL2034',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
# ...
#    'target_chembl_id': 'CHEMBL2973',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '6.0',
#    'Protein': 'ROCK2'},
#   {'assay_chembl_id': 'CHEMBL1960789',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.46',
#    'target_chembl_id': 'CHEMBL2553',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '35.0',
#    'Protein': 'RPS6KA1'},
#   {'assay_chembl_id': 'CHEMBL1960790',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.85',
#    'target_chembl_id': 'CHEMBL4237',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '14.0',
#    'Protein': 'RPS6KA5'},
#   {'assay_chembl_id': 'CHEMBL1960791',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.49',
#    'target_chembl_id': 'CHEMBL4282',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '324.0',
#    'Protein': 'AKT1'},
#   {'assay_chembl_id': 'CHEMBL3383292',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.85',
#    'target_chembl_id': 'CHEMBL3231',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '14.0',
#    'Protein': 'ROCK1'}],
#  'CHEMBL3963965': [{'assay_chembl_id': 'CHEMBL3864384',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.72',
#    'target_chembl_id': 'CHEMBL5747',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.19',
#    'Protein': 'CREBBP'},
#   {'assay_chembl_id': 'CHEMBL4012512',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.89',
#    'target_chembl_id': 'CHEMBL5747',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.13',
#    'Protein': 'CREBBP'},
#   {'assay_chembl_id': 'CHEMBL4012518',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.21',
#    'target_chembl_id': 'CHEMBL229',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.62',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1701224': [{'assay_chembl_id': 'CHEMBL1738445',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.95',
#    'target_chembl_id': 'CHEMBL2889',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.113',
#    'Protein': 'PTPN22'}],
#  'CHEMBL134915': [{'assay_chembl_id': 'CHEMBL3536664',
#    'assay_type': 'A',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.77',
#    'target_chembl_id': 'CHEMBL2145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '170.0',
#    'Protein': 'KMO'},
#   {'assay_chembl_id': 'CHEMBL3630810',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.43',
#    'target_chembl_id': 'CHEMBL2145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '37.0',
#    'Protein': 'KMO'},
#   {'assay_chembl_id': 'CHEMBL4011242',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.43',
#    'target_chembl_id': 'CHEMBL2145',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '37.0',
#    'Protein': 'KMO'}],
#  'CHEMBL23327': [{'assay_chembl_id': 'CHEMBL666135',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.30',
#    'target_chembl_id': 'CHEMBL308',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.05',
#    'Protein': 'CDK1'},
#   {'assay_chembl_id': 'CHEMBL660780',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.40',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '4.0',
#    'Protein': 'CDK2'},
#   {'assay_chembl_id': 'CHEMBL994306',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.16',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '70.0',
#    'Protein': 'CDK2'},
#   {'assay_chembl_id': 'CHEMBL994307',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.46',
#    'target_chembl_id': 'CHEMBL301',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '35.0',
#    'Protein': 'CDK2'},
#   {'assay_chembl_id': 'CHEMBL1051327',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.89',
#    'target_chembl_id': 'CHEMBL4482',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.13',
#    'Protein': 'PAK4'}],
#  'CHEMBL1969664': [{'assay_chembl_id': 'CHEMBL4054237',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.51',
#    'target_chembl_id': 'CHEMBL262',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '31.0',
#    'Protein': 'GSK3B'}],
#  'CHEMBL261849': [{'assay_chembl_id': 'CHEMBL939336',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.52',
#    'target_chembl_id': 'CHEMBL1844',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '30.0',
#    'Protein': 'CSF1R'},
#   {'assay_chembl_id': 'CHEMBL1959323',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.52',
#    'target_chembl_id': 'CHEMBL1844',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.03',
#    'Protein': 'CSF1R'},
#   {'assay_chembl_id': 'CHEMBL4220344',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.22',
#    'target_chembl_id': 'CHEMBL1844',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '60.0',
#    'Protein': 'CSF1R'},
#   {'assay_chembl_id': 'CHEMBL4330216',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL2815',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.88',
#    'Protein': 'NTRK1'},
#   {'assay_chembl_id': 'CHEMBL4330215',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.22',
#    'target_chembl_id': 'CHEMBL1844',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.06',
#    'Protein': 'CSF1R'}],
#  'CHEMBL473967': [{'assay_chembl_id': 'CHEMBL1837163',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.14',
#    'target_chembl_id': 'CHEMBL6009',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '72.0',
#    'Protein': 'DGAT1'}],
#  'CHEMBL79004': [{'assay_chembl_id': 'CHEMBL1062884',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.60',
#    'target_chembl_id': 'CHEMBL1991',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.25',
#    'Protein': 'IKBKB'},
#   {'assay_chembl_id': 'CHEMBL1062887',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.06',
#    'target_chembl_id': 'CHEMBL5407',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.88',
#    'Protein': 'PIM3'},
#   {'assay_chembl_id': 'CHEMBL1070134',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.82',
#    'target_chembl_id': 'CHEMBL1991',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '150.0',
#    'Protein': 'IKBKB'},
#   {'assay_chembl_id': 'CHEMBL4263043',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.06',
#    'target_chembl_id': 'CHEMBL1991',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.087',
#    'Protein': 'IKBKB'},
#   {'assay_chembl_id': 'CHEMBL4263042',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.82',
#    'target_chembl_id': 'CHEMBL1991',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '150.0',
#    'Protein': 'IKBKB'}],
#  'CHEMBL478629': [{'assay_chembl_id': 'CHEMBL989154',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.37',
#    'target_chembl_id': 'CHEMBL5350',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.43',
#    'Protein': 'BMP4'},
#   {'assay_chembl_id': 'CHEMBL1272379',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.70',
#    'target_chembl_id': 'CHEMBL267',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.002',
#    'Protein': 'SRC'},
#   {'assay_chembl_id': 'CHEMBL1272380',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.96',
#    'target_chembl_id': 'CHEMBL2068',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.011',
#    'Protein': 'EPHA2'},
#   {'assay_chembl_id': 'CHEMBL1272381',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.96',
#    'target_chembl_id': 'CHEMBL1868',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.011',
#    'Protein': 'FLT1'},
#   {'assay_chembl_id': 'CHEMBL1272383',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.40',
#    'target_chembl_id': 'CHEMBL279',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.004',
#    'Protein': 'KDR'}],
#  'CHEMBL2029422': [{'assay_chembl_id': 'CHEMBL2032551',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.30',
#    'target_chembl_id': 'CHEMBL4015',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.5',
#    'Protein': 'CCR2'},
#   {'assay_chembl_id': 'CHEMBL2032541',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.28',
#    'target_chembl_id': 'CHEMBL4015',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '5.2',
#    'Protein': 'CCR2'}],
#  'CHEMBL1774055': [{'assay_chembl_id': 'CHEMBL1776839',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.05',
#    'target_chembl_id': 'CHEMBL2148',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.009',
#    'Protein': 'JAK3'},
#   {'assay_chembl_id': 'CHEMBL4429337',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.35',
#    'target_chembl_id': 'CHEMBL2971',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.45',
#    'Protein': 'JAK2'}],
#  'CHEMBL53753': [{'assay_chembl_id': 'CHEMBL676074',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '11.10',
#    'target_chembl_id': 'CHEMBL203',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.008',
#    'Protein': 'EGFR'}],
#  'CHEMBL51314': [{'assay_chembl_id': 'CHEMBL655779',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.70',
#    'target_chembl_id': 'CHEMBL3243',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.2',
#    'Protein': 'PTPRC'},
#   {'assay_chembl_id': 'CHEMBL663367',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.30',
#    'target_chembl_id': 'CHEMBL3837',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.5',
#    'Protein': 'CTSL'},
#   {'assay_chembl_id': 'CHEMBL658351',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.40',
#    'target_chembl_id': 'CHEMBL2954',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.4',
#    'Protein': 'CTSS'}],
#  'CHEMBL303516': [{'assay_chembl_id': 'CHEMBL1040388',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.48',
#    'target_chembl_id': 'CHEMBL225',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '3.3',
#    'Protein': 'HTR2C'}],
#  'CHEMBL557': [{'assay_chembl_id': 'CHEMBL873891',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.62',
#    'target_chembl_id': 'CHEMBL1860',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.24',
#    'Protein': 'THRA'},
#   {'assay_chembl_id': 'CHEMBL814601',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.59',
#    'target_chembl_id': 'CHEMBL1947',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.26',
#    'Protein': 'THRB'},
#   {'assay_chembl_id': 'CHEMBL866541',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.62',
#    'target_chembl_id': 'CHEMBL1860',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.24',
#    'Protein': 'THRA'},
#   {'assay_chembl_id': 'CHEMBL866542',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.59',
#    'target_chembl_id': 'CHEMBL1947',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.26',
#    'Protein': 'THRB'}],
#  'CHEMBL32749': [{'assay_chembl_id': 'CHEMBL4700552',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.12',
#    'target_chembl_id': 'CHEMBL6152',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.75',
#    'Protein': 'SNCA'}],
#  'CHEMBL412099': [{'assay_chembl_id': 'CHEMBL945937',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.00',
#    'target_chembl_id': 'CHEMBL2971',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.1',
#    'Protein': 'JAK2'},
#   {'assay_chembl_id': 'CHEMBL1100215',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.00',
#    'target_chembl_id': 'CHEMBL5658',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.001',
#    'Protein': 'PTGES'},
#   {'assay_chembl_id': 'CHEMBL1686170',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.00',
#    'target_chembl_id': 'CHEMBL5658',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.001',
#    'Protein': 'PTGES'},
#   {'assay_chembl_id': 'CHEMBL2321397',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.00',
#    'target_chembl_id': 'CHEMBL5658',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.001',
#    'Protein': 'PTGES'}],
#  'CHEMBL1548353': [{'assay_chembl_id': 'CHEMBL3269361',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.70',
#    'target_chembl_id': 'CHEMBL2903',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.2',
#    'Protein': 'ALOX15'},
#   {'assay_chembl_id': 'CHEMBL3269373',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '7.00',
#    'target_chembl_id': 'CHEMBL2903',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '0.1',
#    'Protein': 'ALOX15'},
#   {'assay_chembl_id': 'CHEMBL3766390',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.70',
#    'target_chembl_id': 'CHEMBL2903',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '200.0',
#    'Protein': 'ALOX15'}],
#  'CHEMBL1065': [{'assay_chembl_id': 'CHEMBL3106302',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.12',
#    'target_chembl_id': 'CHEMBL1833',
#    'target_organism': 'Homo sapiens',
#    'type': 'Ki',
#    'value': '7.6',
#    'Protein': 'HTR2B'}],
#  'CHEMBL3688339': [{'assay_chembl_id': 'CHEMBL3706362',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '9.40',
#    'target_chembl_id': 'CHEMBL4578',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.4',
#    'Protein': 'MELK'},
#   {'assay_chembl_id': 'CHEMBL3706362',
#    'assay_type': 'B',
#    'bao_label': 'single protein format',
#    'pchembl_value': '8.96',
#    'target_chembl_id': 'CHEMBL4578',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '1.1',
#    'Protein': 'MELK'}],
#  'CHEMBL4460898': [{'assay_chembl_id': 'CHEMBL4618030',
#    'assay_type': 'A',
#    'bao_label': 'single protein format',
#    'pchembl_value': '6.58',
#    'target_chembl_id': 'CHEMBL3180',
#    'target_organism': 'Homo sapiens',
#    'type': 'IC50',
#    'value': '0.26',
#    'Protein': 'CES2'}],
#  ...}

# %%
mechList_2 = chembl2gene2path(chem2Gene_all,mechList)

# %%
from Nmr2Graph import chem2act_rel_2
test = chem2act_rel_2(ActList2gene2Path_3,itmp_Graph)

# %%
from Nmr2Graph import chem2dis_rel

test = chem2dis_rel(drugIndList,itmp_Graph)

# %%
'Protein' in mechList_2['CHEMBL258805'][0]
# Out:
# True

# %%
mechList_2
# Out:
# {'CHEMBL2360079': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'}],
#  'CHEMBL1275': [{'mechanism_of_action': 'Dopamine receptor agonist',
#    'target_chembl_id': 'CHEMBL2096905',
#    'Protein': 'DRD2'}],
#  'CHEMBL3989821': [{'mechanism_of_action': 'Muscle-type nicotinic acetylcholine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2362997',
#    'Protein': 'CHRNA1'}],
#  'CHEMBL1713': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'D2-like dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL2062262': [{'mechanism_of_action': 'Adrenergic receptor alpha-1 agonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL258805': [{'mechanism_of_action': 'Cyclin-dependent kinase 2 inhibitor',
#    'target_chembl_id': 'CHEMBL301',
#    'Protein': 'CDK2'}],
#  'CHEMBL419667': [{'mechanism_of_action': 'Vasopressin V1a receptor antagonist',
#    'target_chembl_id': 'CHEMBL1889',
#    'Protein': 'AVPR1A'},
#   {'mechanism_of_action': 'Oxytocin receptor antagonist',
#    'target_chembl_id': 'CHEMBL2049',
#    'Protein': 'OXTR'}],
#  'CHEMBL937': [{'mechanism_of_action': 'Nematode GABA-A receptor positive modulator',
#    'target_chembl_id': 'CHEMBL2364676'}],
#  'CHEMBL3989556': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'}],
#  'CHEMBL2146063': [{'mechanism_of_action': 'Bacterial 70S ribosome inhibitor',
#    'target_chembl_id': 'CHEMBL2363135',
#    'Protein': 'rpsB'}],
#  'CHEMBL706': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  'CHEMBL456237': [{'mechanism_of_action': 'LXR-beta agonist',
#    'target_chembl_id': 'CHEMBL4093',
#    'Protein': 'NR1H2'},
#   {'mechanism_of_action': 'LXR-alpha agonist',
#    'target_chembl_id': 'CHEMBL2808',
#    'Protein': 'NR1H3'}],
#  'CHEMBL1677': [{'mechanism_of_action': 'Cholinesterases; ACHE & BCHE inhibitor',
#    'target_chembl_id': 'CHEMBL2095233',
#    'Protein': 'BCHE'}],
#  'CHEMBL1200769': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL3189072': [{'mechanism_of_action': 'Integrin alpha-IIb/beta-3 inhibitor',
#    'target_chembl_id': 'CHEMBL2093869',
#    'Protein': 'ITGB3'}],
#  'CHEMBL1200346': [{'mechanism_of_action': 'Diagnostic agent',
#    'target_chembl_id': None}],
#  'CHEMBL1371': [{'mechanism_of_action': 'Intermediate conductance calcium-activated potassium channel protein 4 opener',
#    'target_chembl_id': 'CHEMBL4305',
#    'Protein': 'KCNN4'}],
#  'CHEMBL298019': [{'mechanism_of_action': 'VP1 capsid protein disrupting agent',
#    'target_chembl_id': 'CHEMBL3833484'}],
#  'CHEMBL1200438': [{'mechanism_of_action': 'Cytochrome P450 51 inhibitor',
#    'target_chembl_id': 'CHEMBL1780',
#    'Protein': 'ERG11'}],
#  'CHEMBL1201043': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1201153': [{'mechanism_of_action': 'Beta-2 adrenergic receptor agonist',
#    'target_chembl_id': 'CHEMBL210',
#    'Protein': 'ADRB2'}],
#  'CHEMBL260933': [{'mechanism_of_action': 'Adenosine A2b receptor antagonist',
#    'target_chembl_id': 'CHEMBL255',
#    'Protein': 'ADORA2B'}],
#  'CHEMBL2165191': [{'mechanism_of_action': 'PI3-kinase class I inhibitor',
#    'target_chembl_id': 'CHEMBL3559703',
#    'Protein': 'PIK3R1'}],
#  'CHEMBL1200541': [{'mechanism_of_action': 'Acetylcholinesterase inhibitor',
#    'target_chembl_id': 'CHEMBL220',
#    'Protein': 'ACHE'}],
#  'CHEMBL1200464': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL406381': [{'mechanism_of_action': 'Vascular endothelial growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095227',
#    'Protein': 'FLT1'}],
#  'CHEMBL1200425': [{'mechanism_of_action': 'Monoamine oxidase inhibitor',
#    'target_chembl_id': 'CHEMBL2095205',
#    'Protein': 'MAOA'}],
#  'CHEMBL452461': [{'mechanism_of_action': 'Glutamate [NMDA] receptor antagonist',
#    'target_chembl_id': 'CHEMBL2094124',
#    'Protein': 'GRIN1'}],
#  'CHEMBL18': [{'mechanism_of_action': 'Carbonic anhydrase inhibitor',
#    'target_chembl_id': 'CHEMBL2095180',
#    'Protein': 'CA2'}],
#  'CHEMBL1689': [{'mechanism_of_action': 'Histamine H1 receptor agonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'},
#   {'mechanism_of_action': 'Histamine H2 receptor agonist',
#    'target_chembl_id': 'CHEMBL1941',
#    'Protein': 'HRH2'},
#   {'mechanism_of_action': 'Adrenergic receptor alpha antagonist',
#    'target_chembl_id': 'CHEMBL2095203',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1341': [{'mechanism_of_action': 'Glycine receptor (alpha-1/beta) agonist',
#    'target_chembl_id': 'CHEMBL2363052',
#    'Protein': 'GLRA1'},
#   {'mechanism_of_action': 'GABA-A receptor; anion channel positive modulator',
#    'target_chembl_id': 'CHEMBL2093872',
#    'Protein': 'GABRA1'}],
#  'CHEMBL1230314': [{'mechanism_of_action': 'Estrogen receptor agonist',
#    'target_chembl_id': 'CHEMBL2093866',
#    'Protein': 'ESR2'}],
#  'CHEMBL1430': [{'mechanism_of_action': 'Copper chelating agent',
#    'target_chembl_id': 'CHEMBL2363057'}],
#  'CHEMBL880': [{'mechanism_of_action': 'Human herpesvirus 1 DNA polymerase inhibitor',
#    'target_chembl_id': 'CHEMBL1872'}],
#  'CHEMBL3137301': [{'mechanism_of_action': 'Neprilysin inhibitor',
#    'target_chembl_id': 'CHEMBL1944',
#    'Protein': 'MME'}],
#  'CHEMBL1200660': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL3085504': [{'mechanism_of_action': 'DNA inhibitor',
#    'target_chembl_id': 'CHEMBL2311221'}],
#  'CHEMBL3674570': [{'mechanism_of_action': 'Macrophage colony stimulating factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL1844',
#    'Protein': 'CSF1R'}],
#  'CHEMBL3989868': [{'mechanism_of_action': 'Receptor protein-tyrosine kinase erbB-2 inhibitor',
#    'target_chembl_id': 'CHEMBL1824',
#    'Protein': 'ERBB2'}],
#  'CHEMBL113313': [{'mechanism_of_action': 'Ghrelin receptor agonist',
#    'target_chembl_id': 'CHEMBL4616',
#    'Protein': 'GHSR'}],
#  'CHEMBL494': [{'mechanism_of_action': 'Prostanoid IP receptor agonist',
#    'target_chembl_id': 'CHEMBL1995',
#    'Protein': 'PTGIR'}],
#  'CHEMBL1908394': [{'mechanism_of_action': 'Serine/threonine-protein kinase PLK1 inhibitor',
#    'target_chembl_id': 'CHEMBL3024',
#    'Protein': 'PLK1'}],
#  'CHEMBL3545313': [{'mechanism_of_action': 'ATP-citrate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL3720',
#    'Protein': 'ACLY'}],
#  'CHEMBL384304': [{'mechanism_of_action': 'Cyclin-dependent kinase 1 inhibitor',
#    'target_chembl_id': 'CHEMBL308',
#    'Protein': 'CDK1'},
#   {'mechanism_of_action': 'Cyclin-dependent kinase 2 inhibitor',
#    'target_chembl_id': 'CHEMBL301',
#    'Protein': 'CDK2'},
#   {'mechanism_of_action': 'Cyclin-dependent kinase 4 inhibitor',
#    'target_chembl_id': 'CHEMBL331',
#    'Protein': 'CDK4'}],
#  'CHEMBL448': [{'mechanism_of_action': 'GABA-A receptor; anion channel positive allosteric modulator',
#    'target_chembl_id': 'CHEMBL2093872',
#    'Protein': 'GABRA1'}],
#  'CHEMBL435298': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL2107822': [{'mechanism_of_action': 'Orexin receptor antagonist',
#    'target_chembl_id': 'CHEMBL3307226',
#    'Protein': 'HCRTR2'}],
#  'CHEMBL1201759': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1921976': [{'mechanism_of_action': 'Cytochrome P450 17A1 inhibitor',
#    'target_chembl_id': 'CHEMBL3522',
#    'Protein': 'CYP17A1'}],
#  'CHEMBL2146133': [{'mechanism_of_action': 'Potassium-transporting ATPase inhibitor',
#    'target_chembl_id': 'CHEMBL2095173',
#    'Protein': 'ATP4A'}],
#  'CHEMBL38943': [{'mechanism_of_action': 'Peroxisome proliferator-activated receptor delta agonist',
#    'target_chembl_id': 'CHEMBL3979',
#    'Protein': 'PPARD'}],
#  'CHEMBL1200411': [{'mechanism_of_action': 'D2-like dopamine receptor agonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL1200392': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1393': [{'mechanism_of_action': 'Mineralocorticoid receptor antagonist',
#    'target_chembl_id': 'CHEMBL1994',
#    'Protein': 'NR3C2'}],
#  'CHEMBL1801204': [{'mechanism_of_action': 'Serine/threonine-protein kinase mTOR inhibitor',
#    'target_chembl_id': 'CHEMBL2842',
#    'Protein': 'MTOR'}],
#  'CHEMBL3989562': [{'mechanism_of_action': 'Adrenergic receptor alpha-1 antagonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1423': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'Dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2096905',
#    'Protein': 'DRD2'}],
#  'CHEMBL750': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL600': [{'mechanism_of_action': 'Glutathione precursor',
#    'target_chembl_id': None},
#   {'mechanism_of_action': 'Mycolytic', 'target_chembl_id': None}],
#  'CHEMBL989': [{'mechanism_of_action': 'Glucocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL2034',
#    'Protein': 'NR3C1'}],
#  'CHEMBL1059': [{'mechanism_of_action': 'Voltage-gated calcium channel modulator',
#    'target_chembl_id': 'CHEMBL2363032',
#    'Protein': 'CACNA1H'}],
#  'CHEMBL2107779': [{'mechanism_of_action': 'MAP kinase p38 alpha inhibitor',
#    'target_chembl_id': 'CHEMBL260',
#    'Protein': 'MAPK14'}],
#  'CHEMBL169901': [{'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL106': [{'mechanism_of_action': 'Cytochrome P450 51 inhibitor',
#    'target_chembl_id': 'CHEMBL1780',
#    'Protein': 'ERG11'}],
#  'CHEMBL523299': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'}],
#  'CHEMBL44657': [{'mechanism_of_action': 'DNA topoisomerase II inhibitor',
#    'target_chembl_id': 'CHEMBL2094255',
#    'Protein': 'TOP2A'}],
#  'CHEMBL638': [{'mechanism_of_action': 'Cytochrome P450 51 inhibitor',
#    'target_chembl_id': 'CHEMBL1780',
#    'Protein': 'ERG11'}],
#  'CHEMBL49429': [{'mechanism_of_action': 'Vasopressin V2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL1790',
#    'Protein': 'AVPR2'}],
#  'CHEMBL467399': [{'mechanism_of_action': 'Heat shock protein HSP90 inhibitor',
#    'target_chembl_id': 'CHEMBL2095165',
#    'Protein': 'HSP90AA1'}],
#  'CHEMBL1042': [{'mechanism_of_action': 'Vitamin D receptor agonist',
#    'target_chembl_id': 'CHEMBL1977',
#    'Protein': 'VDR'}],
#  'CHEMBL4297064': [{'mechanism_of_action': 'Serotonin transporter inhibitor',
#    'target_chembl_id': 'CHEMBL228',
#    'Protein': 'SLC6A4'},
#   {'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL29609': [{'mechanism_of_action': 'VP1 capsid protein disrupting agent',
#    'target_chembl_id': 'CHEMBL3833484'}],
#  'CHEMBL1200339': [{'mechanism_of_action': 'Adrenergic receptor alpha-1 agonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL3581693': [{'mechanism_of_action': 'Estrogen receptor alpha antagonist',
#    'target_chembl_id': 'CHEMBL206',
#    'Protein': 'ESR1'}],
#  'CHEMBL1079175': [{'mechanism_of_action': 'Serine/threonine-protein kinase AKT inhibitor',
#    'target_chembl_id': 'CHEMBL2111353',
#    'Protein': 'AKT2'}],
#  'CHEMBL2016681': [{'mechanism_of_action': 'Neuropeptide Y receptor type 5 antagonist',
#    'target_chembl_id': 'CHEMBL4561',
#    'Protein': 'NPY5R'}],
#  'CHEMBL711': [{'mechanism_of_action': 'Vitamin k epoxide reductase complex subunit 1 isoform 1 inhibitor',
#    'target_chembl_id': 'CHEMBL1930',
#    'Protein': 'VKORC1'}],
#  'CHEMBL1421': [{'mechanism_of_action': 'Tyrosine-protein kinase ABL inhibitor',
#    'target_chembl_id': 'CHEMBL1862',
#    'Protein': 'ABL1'},
#   {'mechanism_of_action': 'Platelet-derived growth factor receptor beta inhibitor',
#    'target_chembl_id': 'CHEMBL1913',
#    'Protein': 'PDGFRB'},
#   {'mechanism_of_action': 'Stem cell growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL1936',
#    'Protein': 'KIT'},
#   {'mechanism_of_action': 'Ephrin type-A receptor 2 inhibitor',
#    'target_chembl_id': 'CHEMBL2068',
#    'Protein': 'EPHA2'},
#   {'mechanism_of_action': 'SRC inhibitor',
#    'target_chembl_id': 'CHEMBL2363074',
#    'Protein': 'FYN'},
#   {'mechanism_of_action': 'Bcr/Abl fusion protein',
#    'target_chembl_id': 'CHEMBL2096618',
#    'Protein': 'ABL1'}],
#  'CHEMBL701': [{'mechanism_of_action': 'GABA-B receptor agonist',
#    'target_chembl_id': 'CHEMBL2111463',
#    'Protein': 'GABBR1'}],
#  'CHEMBL2158685': [{'mechanism_of_action': 'Sphingosine kinase 2 inhibitor',
#    'target_chembl_id': 'CHEMBL3023',
#    'Protein': 'SPHK2'}],
#  'CHEMBL110691': [{'mechanism_of_action': 'Progesterone receptor modulator',
#    'target_chembl_id': 'CHEMBL208',
#    'Protein': 'PGR'}],
#  'CHEMBL488937': [{'mechanism_of_action': 'Enoyl-[acyl-carrier-protein] reductase (FabI) inhibitor',
#    'target_chembl_id': 'CHEMBL3994',
#    'Protein': 'fabI'}],
#  'CHEMBL1200542': [{'mechanism_of_action': 'Mineralocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL1994',
#    'Protein': 'NR3C2'}],
#  'CHEMBL311498': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL2079587': [{'mechanism_of_action': 'Androgen Receptor agonist',
#    'target_chembl_id': 'CHEMBL1871',
#    'Protein': 'AR'}],
#  'CHEMBL919': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL1320667': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL571948': [{'mechanism_of_action': 'Rho-associated protein kinase inhibitor',
#    'target_chembl_id': 'CHEMBL2111459',
#    'Protein': 'ROCK2'}],
#  'CHEMBL6466': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  'CHEMBL1201177': [{'mechanism_of_action': 'Beta-1 adrenergic receptor antagonist',
#    'target_chembl_id': 'CHEMBL213',
#    'Protein': 'ADRB1'},
#   {'mechanism_of_action': 'Beta-2 adrenergic receptor antagonist',
#    'target_chembl_id': 'CHEMBL210',
#    'Protein': 'ADRB2'}],
#  'CHEMBL1200432': [{'mechanism_of_action': 'Adrenergic receptor alpha-2 agonist',
#    'target_chembl_id': 'CHEMBL2095158',
#    'Protein': 'ADRA2A'}],
#  'CHEMBL1592101': [{'mechanism_of_action': 'Coagulation factor XII activator',
#    'target_chembl_id': 'CHEMBL2821',
#    'Protein': 'F12'}],
#  'CHEMBL529': [{'mechanism_of_action': 'Bacterial 70S ribosome inhibitor',
#    'target_chembl_id': 'CHEMBL2363135',
#    'Protein': 'rpsB'}],
#  'CHEMBL1401': [{'mechanism_of_action': 'Pyruvate:ferredoxin oxidoreductase inhibitor',
#    'target_chembl_id': 'CHEMBL2364026',
#    'Protein': 'PFOR'},
#   {'mechanism_of_action': 'Pyruvate:ferredoxin oxidoreductase inhibitor',
#    'target_chembl_id': 'CHEMBL2364027'}],
#  'CHEMBL1201110': [{'mechanism_of_action': 'Human herpesvirus 1 DNA polymerase inhibitor',
#    'target_chembl_id': 'CHEMBL1872'}],
#  'CHEMBL270995': [{'mechanism_of_action': 'Fibroblast growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095217',
#    'Protein': 'FGFR3'},
#   {'mechanism_of_action': 'Vascular endothelial growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095227',
#    'Protein': 'FLT1'}],
#  'CHEMBL803': [{'mechanism_of_action': 'DNA inhibitor',
#    'target_chembl_id': 'CHEMBL2311221'},
#   {'mechanism_of_action': 'RNA inhibitor',
#    'target_chembl_id': 'CHEMBL2311222'},
#   {'mechanism_of_action': 'DNA polymerase (alpha/delta/epsilon) inhibitor',
#    'target_chembl_id': 'CHEMBL2363042',
#    'Protein': 'POLA1'}],
#  'CHEMBL1200359': [{'mechanism_of_action': 'Bacterial dihydropteroate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL2364668',
#    'Protein': 'folP'}],
#  'CHEMBL25': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL406393': [{'mechanism_of_action': 'Cell membrane disrupting agent',
#    'target_chembl_id': 'CHEMBL3390826'}],
#  'CHEMBL741': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL281764': [{'mechanism_of_action': 'Ghrelin receptor agonist',
#    'target_chembl_id': 'CHEMBL4616',
#    'Protein': 'GHSR'},
#   {'mechanism_of_action': 'Cytochrome P450 3A4 inhibitor',
#    'target_chembl_id': 'CHEMBL340',
#    'Protein': 'CYP3A4'}],
#  'CHEMBL1562610': [{'mechanism_of_action': 'Arachidonate 5-lipoxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL215',
#    'Protein': 'ALOX5'},
#   {'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL1255739': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1201050': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL139877': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1584': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  'CHEMBL1201006': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL2138684': [{'mechanism_of_action': 'Serotonin 1b (5-HT1b) receptor agonist',
#    'target_chembl_id': 'CHEMBL1898',
#    'Protein': 'HTR1B'},
#   {'mechanism_of_action': 'Serotonin 1d (5-HT1d) receptor agonist',
#    'target_chembl_id': 'CHEMBL1983',
#    'Protein': 'HTR1D'}],
#  'CHEMBL1201038': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1275868': [{'mechanism_of_action': 'Voltage-gated L-type calcium channel blocker',
#    'target_chembl_id': 'CHEMBL2095229',
#    'Protein': 'CACNA1C'}],
#  'CHEMBL462547': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1628569': [{'mechanism_of_action': 'Serotonin 1a (5-HT1a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL214',
#    'Protein': 'HTR1A'}],
#  'CHEMBL1200868': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL224325': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1200437': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL487': [{'mechanism_of_action': 'Estrogen receptor modulator',
#    'target_chembl_id': 'CHEMBL2093866',
#    'Protein': 'ESR2'}],
#  'CHEMBL1200948': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'},
#   {'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'},
#   {'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'Serotonin 2c (5-HT2c) receptor antagonist',
#    'target_chembl_id': 'CHEMBL225',
#    'Protein': 'HTR2C'},
#   {'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'},
#   {'mechanism_of_action': 'Adrenergic receptor alpha-1 antagonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1134': [{'mechanism_of_action': 'Muscle-type nicotinic acetylcholine receptor partial agonist',
#    'target_chembl_id': 'CHEMBL2362997',
#    'Protein': 'CHRNA1'}],
#  'CHEMBL1201044': [{'mechanism_of_action': 'Alpha-1a adrenergic receptor antagonist',
#    'target_chembl_id': 'CHEMBL229',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1257': [{'mechanism_of_action': 'Glycine receptor (alpha-1/beta) positive modulator',
#    'target_chembl_id': 'CHEMBL2363052',
#    'Protein': 'GLRA1'},
#   {'mechanism_of_action': 'GABA-A receptor; anion channel positive modulator',
#    'target_chembl_id': 'CHEMBL2093872',
#    'Protein': 'GABRA1'},
#   {'mechanism_of_action': 'Potassium channel subfamily K member 10 opener',
#    'target_chembl_id': 'CHEMBL2331041',
#    'Protein': 'KCNK10'},
#   {'mechanism_of_action': 'Potassium channel subfamily K member 18 opener',
#    'target_chembl_id': 'CHEMBL2331042',
#    'Protein': 'KCNK18'},
#   {'mechanism_of_action': 'Potassium channel subfamily K member 3 opener',
#    'target_chembl_id': 'CHEMBL2321613',
#    'Protein': 'KCNK3'},
#   {'mechanism_of_action': 'Potassium channel subfamily K member 9 opener',
#    'target_chembl_id': 'CHEMBL2321614',
#    'Protein': 'KCNK9'},
#   {'mechanism_of_action': 'Potassium channel subfamily K member 2 opener',
#    'target_chembl_id': 'CHEMBL2321615',
#    'Protein': 'KCNK2'}],
#  'CHEMBL1742471': [{'mechanism_of_action': 'Histamine H2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL1941',
#    'Protein': 'HRH2'},
#   {'mechanism_of_action': 'Urease inhibitor',
#    'target_chembl_id': 'CHEMBL5325',
#    'Protein': 'ureB'}],
#  'CHEMBL3183453': [{'mechanism_of_action': 'DNA gyrase inhibitor',
#    'target_chembl_id': 'CHEMBL2331040',
#    'Protein': 'gyrB'}],
#  'CHEMBL1213583': [{'mechanism_of_action': 'Progesterone receptor agonist',
#    'target_chembl_id': 'CHEMBL208',
#    'Protein': 'PGR'}],
#  'CHEMBL54349': [{'mechanism_of_action': 'Translocator protein partial agonist',
#    'target_chembl_id': 'CHEMBL5742',
#    'Protein': 'TSPO'}],
#  'CHEMBL2103739': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1200530': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL23293': [{'mechanism_of_action': 'RAS inhibitor',
#    'target_chembl_id': 'CHEMBL4524006',
#    'Protein': 'HRAS'}],
#  'CHEMBL1201075': [{'mechanism_of_action': 'Diagnostic agent',
#    'target_chembl_id': None}],
#  'CHEMBL1200732': [{'mechanism_of_action': 'Glucocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL2034',
#    'Protein': 'NR3C1'}],
#  'CHEMBL1611': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL1201154': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'}],
#  'CHEMBL2062276': [{'mechanism_of_action': 'Mu opioid receptor antagonist',
#    'target_chembl_id': 'CHEMBL233',
#    'Protein': 'OPRM1'},
#   {'mechanism_of_action': 'Kappa opioid receptor partial agonist',
#    'target_chembl_id': 'CHEMBL237',
#    'Protein': 'OPRK1'}],
#  'CHEMBL1736': [{'mechanism_of_action': 'Diagnostic agent',
#    'target_chembl_id': None}],
#  'CHEMBL1354199': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL1237135': [{'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL1200593': [{'mechanism_of_action': 'Diagnostic agent',
#    'target_chembl_id': None}],
#  'CHEMBL24944': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  'CHEMBL375611': [{'mechanism_of_action': 'Metabotropic glutamate receptor 2 agonist',
#    'target_chembl_id': 'CHEMBL5137',
#    'Protein': 'GRM2'},
#   {'mechanism_of_action': 'Metabotropic glutamate receptor 3 agonist',
#    'target_chembl_id': 'CHEMBL2888',
#    'Protein': 'GRM3'}],
#  'CHEMBL3183451': [{'mechanism_of_action': 'Bacterial DNA gyrase inhibitor',
#    'target_chembl_id': 'CHEMBL2311224',
#    'Protein': 'gyrB'},
#   {'mechanism_of_action': 'Topoisomerase IV inhibitor',
#    'target_chembl_id': 'CHEMBL2363076',
#    'Protein': 'parC'}],
#  'CHEMBL1578': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL983': [{'mechanism_of_action': 'Muscle-type nicotinic acetylcholine receptor agonist',
#    'target_chembl_id': 'CHEMBL2362997',
#    'Protein': 'CHRNA1'}],
#  'CHEMBL221692': [{'mechanism_of_action': 'Serotonin 1a (5-HT1a) receptor agonist',
#    'target_chembl_id': 'CHEMBL214',
#    'Protein': 'HTR1A'},
#   {'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'},
#   {'mechanism_of_action': 'Dopamine D3 receptor antagonist',
#    'target_chembl_id': 'CHEMBL234',
#    'Protein': 'DRD3'}],
#  'CHEMBL4297322': [{'mechanism_of_action': 'Serotonin 2b (5-HT2b) receptor antagonist',
#    'target_chembl_id': 'CHEMBL1833',
#    'Protein': 'HTR2B'}],
#  'CHEMBL229430': [{'mechanism_of_action': 'Vanilloid receptor antagonist',
#    'target_chembl_id': 'CHEMBL4794',
#    'Protein': 'TRPV1'}],
#  'CHEMBL475251': [{'mechanism_of_action': 'Tyrosine-protein kinase SYK inhibitor',
#    'target_chembl_id': 'CHEMBL2599',
#    'Protein': 'SYK'}],
#  'CHEMBL1200910': [{'mechanism_of_action': 'Bacterial dihydropteroate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL2364668',
#    'Protein': 'folP'}],
#  'CHEMBL1200592': [{'mechanism_of_action': 'Mineralocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL1994',
#    'Protein': 'NR3C2'}],
#  'CHEMBL1201003': [{'mechanism_of_action': 'Serotonin 1f (5-HT1f) receptor agonist',
#    'target_chembl_id': 'CHEMBL1805',
#    'Protein': 'HTR1F'},
#   {'mechanism_of_action': 'Serotonin 1b (5-HT1b) receptor agonist',
#    'target_chembl_id': 'CHEMBL1898',
#    'Protein': 'HTR1B'},
#   {'mechanism_of_action': 'Serotonin 1d (5-HT1d) receptor agonist',
#    'target_chembl_id': 'CHEMBL1983',
#    'Protein': 'HTR1D'}],
#  'CHEMBL2107572': [{'mechanism_of_action': 'Calcium sensing receptor modulator',
#    'target_chembl_id': 'CHEMBL1878',
#    'Protein': 'CASR'}],
#  'CHEMBL1201102': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'}],
#  'CHEMBL1693': [{'mechanism_of_action': 'Dopamine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL238',
#    'Protein': 'SLC6A3'},
#   {'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL1200560': [{'mechanism_of_action': 'Adrenergic receptor alpha-2 agonist',
#    'target_chembl_id': 'CHEMBL2095158',
#    'Protein': 'ADRA2A'}],
#  'CHEMBL544': [{'mechanism_of_action': 'Tyrosinase inhibitor',
#    'target_chembl_id': 'CHEMBL1973',
#    'Protein': 'TYR'}],
#  'CHEMBL4303241': [{'mechanism_of_action': 'Dual specificity protein kinase TTK inhibitor',
#    'target_chembl_id': 'CHEMBL3983',
#    'Protein': 'TTK'}],
#  'CHEMBL2105740': [{'mechanism_of_action': 'Endothelin receptor, ET-A/ET-B antagonist',
#    'target_chembl_id': 'CHEMBL2096678',
#    'Protein': 'EDNRB'}],
#  'CHEMBL1887891': [{'mechanism_of_action': 'Serotonin (5-HT) receptor agonist',
#    'target_chembl_id': 'CHEMBL2096904',
#    'Protein': 'HTR1F'}],
#  'CHEMBL1200891': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL333826': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL2146102': [{'mechanism_of_action': 'Adrenergic receptor agonist',
#    'target_chembl_id': 'CHEMBL2331074',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL1564': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL535396': [{'mechanism_of_action': 'Influenza virus A matrix protein M2 inhibitor',
#    'target_chembl_id': 'CHEMBL2052',
#    'Protein': 'M'}],
#  'CHEMBL1200852': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL3646118': [{'mechanism_of_action': 'Egl nine homolog 1 inhibitor',
#    'target_chembl_id': 'CHEMBL5697',
#    'Protein': 'EGLN1'},
#   {'mechanism_of_action': 'Hypoxia-inducible factor prolyl hydroxylase 1 inhibitor',
#    'target_chembl_id': 'CHEMBL3028',
#    'Protein': 'EGLN2'},
#   {'mechanism_of_action': 'Egl nine homolog 3 inhibitor',
#    'target_chembl_id': 'CHEMBL5705',
#    'Protein': 'EGLN3'}],
#  'CHEMBL1200875': [{'mechanism_of_action': 'Phosphodiesterase 4 inhibitor',
#    'target_chembl_id': 'CHEMBL2093863',
#    'Protein': 'PDE4A'},
#   {'mechanism_of_action': 'Phosphodiesterase 7 inhibitor',
#    'target_chembl_id': 'CHEMBL2111411',
#    'Protein': 'PDE7A'},
#   {'mechanism_of_action': 'Phosphodiesterase 8 inhibitor',
#    'target_chembl_id': 'CHEMBL2363067',
#    'Protein': 'PDE8B'}],
#  'CHEMBL1200379': [{'mechanism_of_action': 'Adrenergic receptor alpha-2 agonist',
#    'target_chembl_id': 'CHEMBL2095158',
#    'Protein': 'ADRA2A'}],
#  'CHEMBL4303323': [{'mechanism_of_action': 'PI3-kinase p110-delta subunit inhibitor',
#    'target_chembl_id': 'CHEMBL3130',
#    'Protein': 'PIK3CD'}],
#  'CHEMBL1200787': [{'mechanism_of_action': 'Adrenergic receptor alpha antagonist',
#    'target_chembl_id': 'CHEMBL2095203',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL3989478': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'}],
#  'CHEMBL1092665': [{'mechanism_of_action': 'Iron sequestering agent',
#    'target_chembl_id': 'CHEMBL2363058'}],
#  'CHEMBL1528839': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1200880': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL1200988': [{'mechanism_of_action': 'Histamine H2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL1941',
#    'Protein': 'HRH2'}],
#  'CHEMBL2107786': [{'mechanism_of_action': 'Thromboxane A2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL2069',
#    'Protein': 'TBXA2R'}],
#  'CHEMBL46917': [{'mechanism_of_action': 'Acetylcholinesterase inhibitor',
#    'target_chembl_id': 'CHEMBL2362988',
#    'Protein': 'Ace1'}],
#  'CHEMBL1591365': [{'mechanism_of_action': 'Squalene monooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL1888',
#    'Protein': 'ERG1'}],
#  'CHEMBL1200949': [{'mechanism_of_action': 'Histamine H2 receptor agonist',
#    'target_chembl_id': 'CHEMBL1941',
#    'Protein': 'HRH2'}],
#  'CHEMBL1529': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL585902': [{'mechanism_of_action': 'MAP kinase p38 alpha inhibitor',
#    'target_chembl_id': 'CHEMBL260',
#    'Protein': 'MAPK14'}],
#  'CHEMBL123292': [{'mechanism_of_action': '80S Ribosome inhibitor',
#    'target_chembl_id': 'CHEMBL3987582',
#    'Protein': 'RPSA'}],
#  'CHEMBL2107016': [{'mechanism_of_action': 'Thyrotropin-releasing hormone receptor agonist',
#    'target_chembl_id': 'CHEMBL1810',
#    'Protein': 'TRHR'}],
#  'CHEMBL1201035': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL1200469': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'D2-like dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL592374': [{'mechanism_of_action': 'Monoamine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL2363064',
#    'Protein': 'SLC6A4'}],
#  'CHEMBL20': [{'mechanism_of_action': 'Carbonic anhydrase I inhibitor',
#    'target_chembl_id': 'CHEMBL261',
#    'Protein': 'CA1'},
#   {'mechanism_of_action': 'Carbonic anhydrase II inhibitor',
#    'target_chembl_id': 'CHEMBL205',
#    'Protein': 'CA2'},
#   {'mechanism_of_action': 'Carbonic anhydrase XII inhibitor',
#    'target_chembl_id': 'CHEMBL3242',
#    'Protein': 'CA12'},
#   {'mechanism_of_action': 'Carbonic anhydrase IV inhibitor',
#    'target_chembl_id': 'CHEMBL3729',
#    'Protein': 'CA4'}],
#  'CHEMBL266497': [{'mechanism_of_action': 'Aldose reductase inhibitor',
#    'target_chembl_id': 'CHEMBL1900',
#    'Protein': 'AKR1B1'}],
#  'CHEMBL231884': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL24': [{'mechanism_of_action': 'Beta-1 adrenergic receptor antagonist',
#    'target_chembl_id': 'CHEMBL213',
#    'Protein': 'ADRB1'}],
#  'CHEMBL2105728': [{'mechanism_of_action': 'Platelet-derived growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095189',
#    'Protein': 'PDGFRB'},
#   {'mechanism_of_action': 'Tyrosine-protein kinase receptor FLT3 inhibitor',
#    'target_chembl_id': 'CHEMBL1974',
#    'Protein': 'FLT3'}],
#  'CHEMBL2070241': [{'mechanism_of_action': 'Melanocortin receptor 4 agonist',
#    'target_chembl_id': 'CHEMBL259',
#    'Protein': 'MC4R'}],
#  'CHEMBL1723': [{'mechanism_of_action': 'Adrenergic receptor alpha-1 agonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'}],
#  'CHEMBL696': [{'mechanism_of_action': 'Voltage-gated T-type calcium channel blocker',
#    'target_chembl_id': 'CHEMBL2362995',
#    'Protein': 'CACNA1H'}],
#  'CHEMBL91': [{'mechanism_of_action': 'Cytochrome P450 51 inhibitor',
#    'target_chembl_id': 'CHEMBL1780',
#    'Protein': 'ERG11'}],
#  'CHEMBL101': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL3544964': [{'mechanism_of_action': 'MAP kinase ERK1 inhibitor',
#    'target_chembl_id': 'CHEMBL3385',
#    'Protein': 'MAPK3'},
#   {'mechanism_of_action': 'MAP kinase ERK2 inhibitor',
#    'target_chembl_id': 'CHEMBL4040',
#    'Protein': 'MAPK1'}],
#  'CHEMBL1236682': [{'mechanism_of_action': 'Dual specificity mitogen-activated protein kinase kinase 1 inhibitor',
#    'target_chembl_id': 'CHEMBL3587',
#    'Protein': 'MAP2K1'},
#   {'mechanism_of_action': 'Dual specificity mitogen-activated protein kinase kinase 2 inhibitor',
#    'target_chembl_id': 'CHEMBL2964',
#    'Protein': 'MAP2K2'}],
#  'CHEMBL21536': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M4 agonist',
#    'target_chembl_id': 'CHEMBL1821',
#    'Protein': 'CHRM4'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 agonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL1200648': [{'mechanism_of_action': 'Muscle-type nicotinic acetylcholine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2362997',
#    'Protein': 'CHRNA1'}],
#  'CHEMBL4297456': [{'mechanism_of_action': 'Integrin alpha-5/beta-1 antagonist',
#    'target_chembl_id': 'CHEMBL2095226',
#    'Protein': 'ITGB1'},
#   {'mechanism_of_action': 'Integrin alpha-V/beta-3 antagonist',
#    'target_chembl_id': 'CHEMBL1907598',
#    'Protein': 'ITGB3'}],
#  'CHEMBL371064': [{'mechanism_of_action': 'Cathepsin K inhibitor',
#    'target_chembl_id': 'CHEMBL268',
#    'Protein': 'CTSK'}],
#  'CHEMBL1201782': [{'mechanism_of_action': 'Neurokinin 1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL249',
#    'Protein': 'TACR1'}],
#  'CHEMBL598797': [{'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'},
#   {'mechanism_of_action': 'Receptor protein-tyrosine kinase erbB-2 inhibitor',
#    'target_chembl_id': 'CHEMBL1824',
#    'Protein': 'ERBB2'},
#   {'mechanism_of_action': 'Histone deacetylase inhibitor',
#    'target_chembl_id': 'CHEMBL2093865',
#    'Protein': 'HDAC1'}],
#  'CHEMBL1108': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'D2-like dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL1200659': [{'mechanism_of_action': 'Angiotensin-converting enzyme inhibitor',
#    'target_chembl_id': 'CHEMBL1808',
#    'Protein': 'ACE'}],
#  'CHEMBL10878': [{'mechanism_of_action': 'Melatonin receptor agonist',
#    'target_chembl_id': 'CHEMBL2094268',
#    'Protein': 'MTNR1A'},
#   {'mechanism_of_action': 'Serotonin 2c (5-HT2c) receptor antagonist',
#    'target_chembl_id': 'CHEMBL225',
#    'Protein': 'HTR2C'}],
#  'CHEMBL1096': [{'mechanism_of_action': 'Phosphodiesterase 4 inhibitor',
#    'target_chembl_id': 'CHEMBL2093863',
#    'Protein': 'PDE4A'}],
#  'CHEMBL46423': [{'mechanism_of_action': 'Acyl coenzyme A:cholesterol acyltransferase 1 inhibitor',
#    'target_chembl_id': 'CHEMBL2782',
#    'Protein': 'SOAT1'}],
#  'CHEMBL2355456': [{'mechanism_of_action': 'HERG blocker',
#    'target_chembl_id': 'CHEMBL240',
#    'Protein': 'KCNH2'}],
#  'CHEMBL4303201': [{'mechanism_of_action': 'Vascular endothelial growth factor receptor 2 inhibitor',
#    'target_chembl_id': 'CHEMBL279',
#    'Protein': 'KDR'},
#   {'mechanism_of_action': 'Vascular endothelial growth factor receptor 3 inhibitor',
#    'target_chembl_id': 'CHEMBL1955',
#    'Protein': 'FLT4'},
#   {'mechanism_of_action': 'Stem cell growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL1936',
#    'Protein': 'KIT'},
#   {'mechanism_of_action': 'Platelet-derived growth factor receptor beta inhibitor',
#    'target_chembl_id': 'CHEMBL1913',
#    'Protein': 'PDGFRB'}],
#  'CHEMBL3889654': [{'mechanism_of_action': 'Neurotrophic tyrosine kinase receptor inhibitor',
#    'target_chembl_id': 'CHEMBL3559684',
#    'Protein': 'NTRK1'}],
#  'CHEMBL259972': [{'mechanism_of_action': 'Cyclooxygenase-1 inhibitor',
#    'target_chembl_id': 'CHEMBL221',
#    'Protein': 'PTGS1'}],
#  'CHEMBL496': [{'mechanism_of_action': 'Bacterial enoyl-[acyl-carrier-protein] reductase inhibitor',
#    'target_chembl_id': 'CHEMBL2364678',
#    'Protein': 'fabI'}],
#  'CHEMBL1200586': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL607710': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL562': [{'mechanism_of_action': 'Tubulin inhibitor',
#    'target_chembl_id': 'CHEMBL2364703'}],
#  'CHEMBL779': [{'mechanism_of_action': 'Phosphodiesterase 5A inhibitor',
#    'target_chembl_id': 'CHEMBL1827',
#    'Protein': 'PDE5A'}],
#  'CHEMBL1200517': [{'mechanism_of_action': 'Serotonin 1d (5-HT1d) receptor agonist',
#    'target_chembl_id': 'CHEMBL1983',
#    'Protein': 'HTR1D'}],
#  'CHEMBL1201066': [{'mechanism_of_action': 'Serotonin transporter inhibitor',
#    'target_chembl_id': 'CHEMBL228',
#    'Protein': 'SLC6A4'},
#   {'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL135': [{'mechanism_of_action': 'Estrogen receptor alpha agonist',
#    'target_chembl_id': 'CHEMBL206',
#    'Protein': 'ESR1'}],
#  'CHEMBL1223': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1201132': [{'mechanism_of_action': 'Opioid receptors; mu/kappa/delta agonist',
#    'target_chembl_id': 'CHEMBL2095181',
#    'Protein': 'OPRK1'}],
#  'CHEMBL2392545': [{'mechanism_of_action': 'Serine/threonine-protein kinase PLK1 inhibitor',
#    'target_chembl_id': 'CHEMBL3024',
#    'Protein': 'PLK1'}],
#  'CHEMBL1200761': [{'mechanism_of_action': 'Estrogen receptor beta modulator',
#    'target_chembl_id': 'CHEMBL242',
#    'Protein': 'ESR2'}],
#  'CHEMBL1497': [{'mechanism_of_action': 'Glucocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL2034',
#    'Protein': 'NR3C1'}],
#  'CHEMBL21': [{'mechanism_of_action': 'Bacterial dihydropteroate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL2364668',
#    'Protein': 'folP'}],
#  'CHEMBL3353410': [{'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'}],
#  'CHEMBL1090771': [{'mechanism_of_action': 'Gamma-secretase inhibitor',
#    'target_chembl_id': 'CHEMBL2094135',
#    'Protein': 'APH1A'}],
#  'CHEMBL2103842': [{'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'},
#   {'mechanism_of_action': 'Receptor protein-tyrosine kinase erbB-2 inhibitor',
#    'target_chembl_id': 'CHEMBL1824',
#    'Protein': 'ERBB2'}],
#  'CHEMBL1200885': [{'mechanism_of_action': 'Serotonin 3a (5-HT3a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL1899',
#    'Protein': 'HTR3A'}],
#  'CHEMBL2103795': [{'mechanism_of_action': 'Type-1 angiotensin II receptor antagonist',
#    'target_chembl_id': 'CHEMBL227',
#    'Protein': 'AGTR1'}],
#  'CHEMBL964': [{'mechanism_of_action': 'Aldehyde dehydrogenase inhibitor',
#    'target_chembl_id': 'CHEMBL1935',
#    'Protein': 'ALDH2'}],
#  'CHEMBL2107384': [{'mechanism_of_action': 'C-C chemokine receptor type 5 antagonist',
#    'target_chembl_id': 'CHEMBL274',
#    'Protein': 'CCR5'}],
#  'CHEMBL1720': [{'mechanism_of_action': 'Serotonin 3a (5-HT3a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL1899',
#    'Protein': 'HTR3A'}],
#  'CHEMBL477': [{'mechanism_of_action': 'Adenosine receptor agonist',
#    'target_chembl_id': 'CHEMBL2111329',
#    'Protein': 'ADORA1'}],
#  'CHEMBL483321': [{'mechanism_of_action': 'Receptor protein-tyrosine kinase erbB-2 inhibitor',
#    'target_chembl_id': 'CHEMBL1824',
#    'Protein': 'ERBB2'}],
#  'CHEMBL1201117': [{'mechanism_of_action': 'Carbonic anhydrase I inhibitor',
#    'target_chembl_id': 'CHEMBL261',
#    'Protein': 'CA1'}],
#  'CHEMBL1200848': [{'mechanism_of_action': 'Progesterone receptor agonist',
#    'target_chembl_id': 'CHEMBL208',
#    'Protein': 'PGR'}],
#  'CHEMBL260046': [{'mechanism_of_action': 'DNA inhibitor',
#    'target_chembl_id': 'CHEMBL2311221'}],
#  'CHEMBL492399': [{'mechanism_of_action': 'Tubulin disrupting agent',
#    'target_chembl_id': 'CHEMBL2095182',
#    'Protein': 'TUBB4B'}],
#  'CHEMBL455136': [{'mechanism_of_action': 'Orexin receptor antagonist',
#    'target_chembl_id': 'CHEMBL3307226',
#    'Protein': 'HCRTR2'}],
#  'CHEMBL19236': [{'mechanism_of_action': 'Nischarin agonist',
#    'target_chembl_id': 'CHEMBL3923',
#    'Protein': 'NISCH'}],
#  'CHEMBL744': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL1684': [{'mechanism_of_action': 'Thiazide-sensitive sodium-chloride cotransporter inhibitor',
#    'target_chembl_id': 'CHEMBL1876',
#    'Protein': 'SLC12A3'}],
#  'CHEMBL2062335': [{'mechanism_of_action': 'Beta-1 adrenergic receptor antagonist',
#    'target_chembl_id': 'CHEMBL213',
#    'Protein': 'ADRB1'}],
#  'CHEMBL3410450': [{'mechanism_of_action': 'Fusion glycoprotein F0 inhibitor',
#    'target_chembl_id': 'CHEMBL3856166',
#    'Protein': 'F'}],
#  'CHEMBL9967': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL2347655': [{'mechanism_of_action': 'Kinesin-like protein 1 inhibitor',
#    'target_chembl_id': 'CHEMBL4581',
#    'Protein': 'KIF11'}],
#  'CHEMBL1616': [{'mechanism_of_action': 'D2-like dopamine receptor agonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL1200950': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'}],
#  'CHEMBL953': [{'mechanism_of_action': 'Catechol O-methyltransferase inhibitor',
#    'target_chembl_id': 'CHEMBL2023',
#    'Protein': 'COMT'}],
#  'CHEMBL91397': [{'mechanism_of_action': 'Platelet activating factor receptor antagonist',
#    'target_chembl_id': 'CHEMBL250',
#    'Protein': 'PTAFR'},
#   {'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1696': [{'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL12713': [{'mechanism_of_action': 'Dopamine D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL217',
#    'Protein': 'DRD2'},
#   {'mechanism_of_action': 'Adrenergic receptor alpha-1 antagonist',
#    'target_chembl_id': 'CHEMBL2094251',
#    'Protein': 'ADRA1A'},
#   {'mechanism_of_action': 'Serotonin 2 receptors; 5-HT2a & 5-HT2c antagonist',
#    'target_chembl_id': 'CHEMBL2096662',
#    'Protein': 'HTR2A'}],
#  'CHEMBL1201156': [{'mechanism_of_action': 'Serotonin transporter inhibitor',
#    'target_chembl_id': 'CHEMBL228',
#    'Protein': 'SLC6A4'},
#   {'mechanism_of_action': 'Norepinephrine transporter inhibitor',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL43064': [{'mechanism_of_action': 'Voltage-gated L-type calcium channel blocker',
#    'target_chembl_id': 'CHEMBL2095229',
#    'Protein': 'CACNA1C'},
#   {'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL14': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 agonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'}],
#  'CHEMBL17350': [{'mechanism_of_action': 'Glutamate NMDA receptor; GRIN1/GRIN2B antagonist',
#    'target_chembl_id': 'CHEMBL1907603',
#    'Protein': 'GRIN1'}],
#  'CHEMBL363648': [{'mechanism_of_action': 'MAP kinase p38 alpha inhibitor',
#    'target_chembl_id': 'CHEMBL260',
#    'Protein': 'MAPK14'}],
#  'CHEMBL1201129': [{'mechanism_of_action': 'DNA (cytosine-5)-methyltransferase 3A inhibitor',
#    'target_chembl_id': 'CHEMBL1992',
#    'Protein': 'DNMT3A'},
#   {'mechanism_of_action': 'DNA (cytosine-5)-methyltransferase 1 inhibitor',
#    'target_chembl_id': 'CHEMBL1993',
#    'Protein': 'DNMT1'},
#   {'mechanism_of_action': 'DNA inhibitor',
#    'target_chembl_id': 'CHEMBL2311221'}],
#  'CHEMBL3590674': [{'mechanism_of_action': 'Voltage-gated T-type calcium channel alpha-1H subunit blocker',
#    'target_chembl_id': 'CHEMBL1859',
#    'Protein': 'CACNA1H'}],
#  'CHEMBL1557': [{'mechanism_of_action': 'Beta-1 adrenergic receptor agonist',
#    'target_chembl_id': 'CHEMBL213',
#    'Protein': 'ADRB1'}],
#  'CHEMBL4582651': [{'mechanism_of_action': 'Tyrosine-protein kinase receptor RET inhibitor',
#    'target_chembl_id': 'CHEMBL2041',
#    'Protein': 'RET'},
#   {'mechanism_of_action': 'Coiled-coil domain-containing protein 6/Tyrosine-protein kinase receptor RET inhibitor',
#    'target_chembl_id': 'CHEMBL3430904',
#    'Protein': 'RET'},
#   {'mechanism_of_action': 'Kinesin-1 heavy chain/ Tyrosine-protein kinase receptor RET inhibitor',
#    'target_chembl_id': 'CHEMBL3430888',
#    'Protein': 'RET'}],
#  'CHEMBL1138': [{'mechanism_of_action': 'Niemann-Pick C1-like protein 1 inhibitor',
#    'target_chembl_id': 'CHEMBL2027',
#    'Protein': 'NPC1L1'}],
#  'CHEMBL254328': [{'mechanism_of_action': 'Cytochrome P450 17A1 inhibitor',
#    'target_chembl_id': 'CHEMBL3522',
#    'Protein': 'CYP17A1'},
#   {'mechanism_of_action': 'Androgen Receptor antagonist',
#    'target_chembl_id': 'CHEMBL1871',
#    'Protein': 'AR'},
#   {'mechanism_of_action': 'Steroid 5-alpha-reductase inhibitor',
#    'target_chembl_id': 'CHEMBL2363075',
#    'Protein': 'SRD5A1'}],
#  'CHEMBL1515': [{'mechanism_of_action': 'Thyroid peroxidase inhibitor',
#    'target_chembl_id': 'CHEMBL1839',
#    'Protein': 'TPO'}],
#  'CHEMBL3039498': [{'mechanism_of_action': 'Prostanoid EP4 receptor antagonist',
#    'target_chembl_id': 'CHEMBL1836',
#    'Protein': 'PTGER4'}],
#  'CHEMBL3188386': [{'mechanism_of_action': 'Probable protein-cysteine N-palmitoyltransferase porcupine inhibitor',
#    'target_chembl_id': 'CHEMBL1255163',
#    'Protein': 'PORCN'}],
#  'CHEMBL496102': [{'mechanism_of_action': 'Hepatocyte growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL3717',
#    'Protein': 'MET'}],
#  'CHEMBL44354': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL175': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
# ...
#  'CHEMBL608533': [{'mechanism_of_action': 'Tyrosine-protein kinase receptor FLT3 inhibitor',
#    'target_chembl_id': 'CHEMBL1974',
#    'Protein': 'FLT3'},
#   {'mechanism_of_action': 'Stem cell growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL1936',
#    'Protein': 'KIT'},
#   {'mechanism_of_action': 'Platelet-derived growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095189',
#    'Protein': 'PDGFRB'},
#   {'mechanism_of_action': 'Protein kinase C (PKC) inhibitor',
#    'target_chembl_id': 'CHEMBL2093867',
#    'Protein': 'PRKD3'},
#   {'mechanism_of_action': 'Vascular endothelial growth factor receptor 2 inhibitor',
#    'target_chembl_id': 'CHEMBL279',
#    'Protein': 'KDR'}],
#  'CHEMBL64': [{'mechanism_of_action': 'Enoyl-[acyl-carrier-protein] reductase inhibitor',
#    'target_chembl_id': 'CHEMBL1849',
#    'Protein': 'inhA'}],
#  'CHEMBL4297422': [{'mechanism_of_action': 'Gamma-secretase inhibitor',
#    'target_chembl_id': 'CHEMBL2094135',
#    'Protein': 'APH1A'}],
#  'CHEMBL416146': [{'mechanism_of_action': 'Cyclooxygenase-2 inhibitor',
#    'target_chembl_id': 'CHEMBL230',
#    'Protein': 'PTGS2'}],
#  'CHEMBL1088750': [{'mechanism_of_action': 'MAP kinase p38 alpha inhibitor',
#    'target_chembl_id': 'CHEMBL260',
#    'Protein': 'MAPK14'}],
#  'CHEMBL1280': [{'mechanism_of_action': 'Voltage-gated L-type calcium channel blocker',
#    'target_chembl_id': 'CHEMBL2095229',
#    'Protein': 'CACNA1C'}],
#  'CHEMBL443684': [{'mechanism_of_action': 'Apoptosis regulator Bcl-2 inhibitor',
#    'target_chembl_id': 'CHEMBL4860',
#    'Protein': 'BCL2'},
#   {'mechanism_of_action': 'Apoptosis regulator Bcl-X inhibitor',
#    'target_chembl_id': 'CHEMBL4625',
#    'Protein': 'BCL2L1'},
#   {'mechanism_of_action': 'Apoptosis regulator Bcl-W inhibitor',
#    'target_chembl_id': 'CHEMBL4677',
#    'Protein': 'BCL2L2'}],
#  'CHEMBL697': [{'mechanism_of_action': 'Voltage-gated T-type calcium channel blocker',
#    'target_chembl_id': 'CHEMBL2362995',
#    'Protein': 'CACNA1H'}],
#  'CHEMBL2105747': [{'mechanism_of_action': 'Adenosine A2a receptor antagonist',
#    'target_chembl_id': 'CHEMBL251',
#    'Protein': 'ADORA2A'}],
#  'CHEMBL431733': [{'mechanism_of_action': 'Adenosine A3 receptor agonist',
#    'target_chembl_id': 'CHEMBL256',
#    'Protein': 'ADORA3'}],
#  'CHEMBL1201032': [{'mechanism_of_action': 'Serotonin 1b (5-HT1b) receptor agonist',
#    'target_chembl_id': 'CHEMBL1898',
#    'Protein': 'HTR1B'},
#   {'mechanism_of_action': 'Serotonin 1d (5-HT1d) receptor agonist',
#    'target_chembl_id': 'CHEMBL1983',
#    'Protein': 'HTR1D'}],
#  'CHEMBL4297865': [{'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'},
#   {'mechanism_of_action': 'Tyrosine-protein kinase BTK inhibitor',
#    'target_chembl_id': 'CHEMBL5251',
#    'Protein': 'BTK'},
#   {'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'}],
#  'CHEMBL436': [{'mechanism_of_action': 'Aldose reductase inhibitor',
#    'target_chembl_id': 'CHEMBL1900',
#    'Protein': 'AKR1B1'}],
#  'CHEMBL1201059': [{'mechanism_of_action': 'Dihydrofolate reductase inhibitor',
#    'target_chembl_id': 'CHEMBL1939'}],
#  'CHEMBL3545413': [{'mechanism_of_action': 'Tyrosine-protein kinase ABL inhibitor',
#    'target_chembl_id': 'CHEMBL1862',
#    'Protein': 'ABL1'}],
#  'CHEMBL374731': [{'mechanism_of_action': 'DNA polymerase/reverse transcriptase inhibitor',
#    'target_chembl_id': 'CHEMBL2362994',
#    'Protein': 'P'}],
#  'CHEMBL3188551': [{'mechanism_of_action': 'PI3-kinase p110-beta subunit inhibitor',
#    'target_chembl_id': 'CHEMBL3145',
#    'Protein': 'PIK3CB'}],
#  'CHEMBL1413': [{'mechanism_of_action': 'Iron chelating agent',
#    'target_chembl_id': 'CHEMBL2363058'},
#   {'mechanism_of_action': 'Aluminium chelating agent',
#    'target_chembl_id': 'CHEMBL2366381'}],
#  'CHEMBL497939': [{'mechanism_of_action': 'Neuronal acetylcholine receptor; alpha4/beta2 partial agonist',
#    'target_chembl_id': 'CHEMBL1907589',
#    'Protein': 'CHRNB2'}],
#  'CHEMBL2041933': [{'mechanism_of_action': 'Serine/threonine-protein kinase Chk1 inhibitor',
#    'target_chembl_id': 'CHEMBL4630',
#    'Protein': 'CHEK1'}],
#  'CHEMBL691': [{'mechanism_of_action': 'Estrogen receptor alpha agonist',
#    'target_chembl_id': 'CHEMBL206',
#    'Protein': 'ESR1'}],
#  'CHEMBL566534': [{'mechanism_of_action': 'Ferriprotoporphyrin IX inhibitor',
#    'target_chembl_id': 'CHEMBL613897'}],
#  'CHEMBL96172': [{'mechanism_of_action': 'Tubulin stabiliser',
#    'target_chembl_id': 'CHEMBL2095182',
#    'Protein': 'TUBB4B'}],
#  'CHEMBL1481': [{'mechanism_of_action': 'Sulfonylurea receptor 1, Kir6.2 blocker',
#    'target_chembl_id': 'CHEMBL2096972',
#    'Protein': 'KCNJ11'}],
#  'CHEMBL2360464': [{'mechanism_of_action': 'Thymidylate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL1952',
#    'Protein': 'TYMS'},
#   {'mechanism_of_action': 'Dihydrofolate reductase inhibitor',
#    'target_chembl_id': 'CHEMBL202',
#    'Protein': 'DHFR'},
#   {'mechanism_of_action': 'GAR transformylase inhibitor',
#    'target_chembl_id': 'CHEMBL3972',
#    'Protein': 'GART'}],
#  'CHEMBL1200340': [{'mechanism_of_action': 'Neuraminidase inhibitor',
#    'target_chembl_id': 'CHEMBL2051',
#    'Protein': 'NA'},
#   {'mechanism_of_action': 'Neuraminidase inhibitor',
#    'target_chembl_id': 'CHEMBL3377',
#    'Protein': 'NA'}],
#  'CHEMBL1286': [{'mechanism_of_action': 'Synaptic vesicle glycoprotein 2A modulator',
#    'target_chembl_id': 'CHEMBL1998',
#    'Protein': 'SV2A'},
#   {'mechanism_of_action': 'Voltage-gated N-type calcium channel alpha-1B subunit blocker',
#    'target_chembl_id': 'CHEMBL4478',
#    'Protein': 'CACNA1B'}],
#  'CHEMBL1159650': [{'mechanism_of_action': 'Glucocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL2034',
#    'Protein': 'NR3C1'}],
#  'CHEMBL518924': [{'mechanism_of_action': 'C-X-C chemokine receptor type 4 antagonist',
#    'target_chembl_id': 'CHEMBL2107',
#    'Protein': 'CXCR4'}],
#  'CHEMBL1957287': [{'mechanism_of_action': 'Hepatitis C virus NS5B RNA-dependent RNA polymerase inhibitor',
#    'target_chembl_id': 'CHEMBL5375',
#    'Protein': 'NS5B'}],
#  'CHEMBL1141': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  'CHEMBL463981': [{'mechanism_of_action': 'Gamma-secretase inhibitor',
#    'target_chembl_id': 'CHEMBL2094135',
#    'Protein': 'APH1A'}],
#  'CHEMBL1201064': [{'mechanism_of_action': 'Glucocorticoid receptor agonist',
#    'target_chembl_id': 'CHEMBL2034',
#    'Protein': 'NR3C1'}],
#  'CHEMBL1201118': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1089221': [{'mechanism_of_action': 'Xanthine dehydrogenase inhibitor',
#    'target_chembl_id': 'CHEMBL1929',
#    'Protein': 'XDH'}],
#  'CHEMBL1231723': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1240': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M1 antagonist',
#    'target_chembl_id': 'CHEMBL216',
#    'Protein': 'CHRM1'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M2 antagonist',
#    'target_chembl_id': 'CHEMBL211',
#    'Protein': 'CHRM2'}],
#  'CHEMBL782': [{'mechanism_of_action': 'Sulfonylurea receptor 1, Kir6.2 blocker',
#    'target_chembl_id': 'CHEMBL2096972',
#    'Protein': 'KCNJ11'}],
#  'CHEMBL3337527': [{'mechanism_of_action': 'Metabotropic glutamate receptor 2 positive allosteric modulator',
#    'target_chembl_id': 'CHEMBL5137',
#    'Protein': 'GRM2'}],
#  'CHEMBL1265': [{'mechanism_of_action': 'Retinoic acid receptor agonist',
#    'target_chembl_id': 'CHEMBL2363069',
#    'Protein': 'RARG'}],
#  'CHEMBL1096979': [{'mechanism_of_action': 'DOPA decarboxylase inhibitor',
#    'target_chembl_id': 'CHEMBL1843',
#    'Protein': 'DDC'}],
#  'CHEMBL3989834': [{'mechanism_of_action': 'Endothelin receptor ET-A antagonist',
#    'target_chembl_id': 'CHEMBL252',
#    'Protein': 'EDNRA'}],
#  'CHEMBL1200589': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1740659': [{'mechanism_of_action': 'Supplement',
#    'target_chembl_id': None}],
#  'CHEMBL1345': [{'mechanism_of_action': 'Norepinephrine transporter substrate',
#    'target_chembl_id': 'CHEMBL222',
#    'Protein': 'SLC6A2'}],
#  'CHEMBL1257040': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'Serotonin 2c (5-HT2c) receptor antagonist',
#    'target_chembl_id': 'CHEMBL225',
#    'Protein': 'HTR2C'},
#   {'mechanism_of_action': 'D2-like dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL262075': [{'mechanism_of_action': 'GABA receptor alpha-1 subunit positive allosteric modulator',
#    'target_chembl_id': 'CHEMBL1962',
#    'Protein': 'GABRA1'}],
#  'CHEMBL15770': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL1764': [{'mechanism_of_action': 'D2-like dopamine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2331075',
#    'Protein': 'DRD2'}],
#  'CHEMBL1021': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL439': [{'mechanism_of_action': 'Bacterial dihydropteroate synthase inhibitor',
#    'target_chembl_id': 'CHEMBL2364668',
#    'Protein': 'folP'}],
#  'CHEMBL445813': [{'mechanism_of_action': 'Cyclin-dependent kinase inhibitor',
#    'target_chembl_id': 'CHEMBL3559691',
#    'Protein': 'CDK1'}],
#  'CHEMBL3545376': [{'mechanism_of_action': 'Fibroblast growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL2095217',
#    'Protein': 'FGFR3'}],
#  'CHEMBL1079742': [{'mechanism_of_action': 'Epidermal growth factor receptor erbB1 inhibitor',
#    'target_chembl_id': 'CHEMBL203',
#    'Protein': 'EGFR'}],
#  'CHEMBL418995': [{'mechanism_of_action': 'Dopamine D1 and D2 receptor antagonist',
#    'target_chembl_id': 'CHEMBL2111341',
#    'Protein': 'DRD2'}],
#  'CHEMBL822': [{'mechanism_of_action': 'Squalene monooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2364679'}],
#  'CHEMBL48582': [{'mechanism_of_action': 'Monoamine oxidase B inhibitor',
#    'target_chembl_id': 'CHEMBL2039',
#    'Protein': 'MAOB'}],
#  'CHEMBL313971': [{'mechanism_of_action': 'Vanilloid receptor agonist',
#    'target_chembl_id': 'CHEMBL4794',
#    'Protein': 'TRPV1'}],
#  'CHEMBL433': [{'mechanism_of_action': 'Succinate semialdehyde dehydrogenase inhibitor',
#    'target_chembl_id': 'CHEMBL1911',
#    'Protein': 'ALDH5A1'}],
#  'CHEMBL483158': [{'mechanism_of_action': 'Serine/threonine-protein kinase Aurora-A inhibitor',
#    'target_chembl_id': 'CHEMBL4722',
#    'Protein': 'AURKA'}],
#  'CHEMBL1201022': [{'mechanism_of_action': 'Sodium channel alpha subunit blocker',
#    'target_chembl_id': 'CHEMBL2331043',
#    'Protein': 'SCN1A'}],
#  'CHEMBL984': [{'mechanism_of_action': 'Muscle-type nicotinic acetylcholine receptor antagonist',
#    'target_chembl_id': 'CHEMBL2362997',
#    'Protein': 'CHRNA1'}],
#  'CHEMBL362558': [{'mechanism_of_action': 'Glycogen synthase kinase-3 beta inhibitor',
#    'target_chembl_id': 'CHEMBL262',
#    'Protein': 'GSK3B'},
#   {'mechanism_of_action': 'Glycogen synthase kinase-3 alpha inhibitor',
#    'target_chembl_id': 'CHEMBL2850',
#    'Protein': 'GSK3A'}],
#  'CHEMBL479527': [{'mechanism_of_action': 'Cholesteryl ester transfer protein inhibitor',
#    'target_chembl_id': 'CHEMBL3572',
#    'Protein': 'CETP'}],
#  'CHEMBL398435': [{'mechanism_of_action': 'Purinergic receptor P2Y12 negative allosteric modulator',
#    'target_chembl_id': 'CHEMBL2001',
#    'Protein': 'P2RY12'}],
#  'CHEMBL654': [{'mechanism_of_action': 'Serotonin 2a (5-HT2a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL224',
#    'Protein': 'HTR2A'},
#   {'mechanism_of_action': 'Serotonin 2c (5-HT2c) receptor antagonist',
#    'target_chembl_id': 'CHEMBL225',
#    'Protein': 'HTR2C'},
#   {'mechanism_of_action': 'Adrenergic receptor alpha-2 antagonist',
#    'target_chembl_id': 'CHEMBL2095158',
#    'Protein': 'ADRA2A'}],
#  'CHEMBL1071': [{'mechanism_of_action': 'Cyclooxygenase inhibitor',
#    'target_chembl_id': 'CHEMBL2094253',
#    'Protein': 'PTGS2'}],
#  'CHEMBL512351': [{'mechanism_of_action': 'Coagulation factor X inhibitor',
#    'target_chembl_id': 'CHEMBL244',
#    'Protein': 'F10'}],
#  'CHEMBL408513': [{'mechanism_of_action': 'Histone deacetylase inhibitor',
#    'target_chembl_id': 'CHEMBL2093865',
#    'Protein': 'HDAC1'}],
#  'CHEMBL3183968': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1607273': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL506871': [{'mechanism_of_action': 'PARP 1, 2 and 3 inhibitor',
#    'target_chembl_id': 'CHEMBL3390820',
#    'Protein': 'PARP1'}],
#  'CHEMBL429910': [{'mechanism_of_action': 'Sodium/glucose cotransporter 2 inhibitor',
#    'target_chembl_id': 'CHEMBL3884',
#    'Protein': 'SLC5A2'}],
#  'CHEMBL1201765': [{'mechanism_of_action': 'Muscarinic acetylcholine receptor M3 antagonist',
#    'target_chembl_id': 'CHEMBL245',
#    'Protein': 'CHRM3'},
#   {'mechanism_of_action': 'Muscarinic acetylcholine receptor M2 antagonist',
#    'target_chembl_id': 'CHEMBL211',
#    'Protein': 'CHRM2'}],
#  'CHEMBL1095930': [{'mechanism_of_action': 'Bacterial penicillin-binding protein inhibitor',
#    'target_chembl_id': 'CHEMBL2354204',
#    'Protein': 'dacB'}],
#  'CHEMBL1642': [{'mechanism_of_action': 'Tyrosine-protein kinase ABL inhibitor',
#    'target_chembl_id': 'CHEMBL1862',
#    'Protein': 'ABL1'},
#   {'mechanism_of_action': 'Platelet-derived growth factor receptor beta inhibitor',
#    'target_chembl_id': 'CHEMBL1913',
#    'Protein': 'PDGFRB'},
#   {'mechanism_of_action': 'Stem cell growth factor receptor inhibitor',
#    'target_chembl_id': 'CHEMBL1936',
#    'Protein': 'KIT'},
#   {'mechanism_of_action': 'Bcr/Abl fusion protein',
#    'target_chembl_id': 'CHEMBL2096618',
#    'Protein': 'ABL1'}],
#  'CHEMBL289351': [{'mechanism_of_action': 'Tubulin inhibitor',
#    'target_chembl_id': 'CHEMBL2095182',
#    'Protein': 'TUBB4B'}],
#  'CHEMBL1200406': [{'mechanism_of_action': 'Histamine H1 receptor antagonist',
#    'target_chembl_id': 'CHEMBL231',
#    'Protein': 'HRH1'}],
#  'CHEMBL1474889': [{'mechanism_of_action': 'Unknown',
#    'target_chembl_id': None}],
#  'CHEMBL1171829': [{'mechanism_of_action': 'Glycine transporter 1 inhibitor',
#    'target_chembl_id': 'CHEMBL2337',
#    'Protein': 'SLC6A9'}],
#  'CHEMBL2147777': [{'mechanism_of_action': 'Dipeptidyl peptidase IV inhibitor',
#    'target_chembl_id': 'CHEMBL284',
#    'Protein': 'DPP4'}],
#  'CHEMBL1521': [{'mechanism_of_action': 'GABA A receptor alpha-1/beta-1/gamma-2 positive allosteric modulator',
#    'target_chembl_id': 'CHEMBL2111392',
#    'Protein': 'GABRA1'}],
#  'CHEMBL2104967': [{'mechanism_of_action': 'Integrin alpha-4/beta-1 antagonist',
#    'target_chembl_id': 'CHEMBL1907599',
#    'Protein': 'ITGB1'},
#   {'mechanism_of_action': 'Integrin alpha-4/beta-7 antagonist',
#    'target_chembl_id': 'CHEMBL2095184',
#    'Protein': 'ITGA4'}],
#  'CHEMBL1200678': [{'mechanism_of_action': 'Human immunodeficiency virus type 1 protease inhibitor',
#    'target_chembl_id': 'CHEMBL243',
#    'Protein': 'pol'}],
#  'CHEMBL301742': [{'mechanism_of_action': 'GABA-B receptor agonist',
#    'target_chembl_id': 'CHEMBL2111463',
#    'Protein': 'GABBR1'}],
#  'CHEMBL46': [{'mechanism_of_action': 'Serotonin 3a (5-HT3a) receptor antagonist',
#    'target_chembl_id': 'CHEMBL1899',
#    'Protein': 'HTR3A'}],
#  'CHEMBL636': [{'mechanism_of_action': 'Cholinesterases; ACHE & BCHE inhibitor',
#    'target_chembl_id': 'CHEMBL2095233',
#    'Protein': 'BCHE'}],
#  'CHEMBL355200': [{'mechanism_of_action': 'Dihydropyrimidine dehydrogenase inhibitor',
#    'target_chembl_id': 'CHEMBL3172',
#    'Protein': 'DPYD'}],
#  'CHEMBL70927': [{'mechanism_of_action': 'Unknown', 'target_chembl_id': None}],
#  ...}

# %%
#Functions for creating graph
def chem2moa_rel_2(named_mechList,itmpGraph):
    for i in named_mechList:
    #print(i)
    #break
    #print(named_mechList[i])
    #print(len(named_mechList[i]))
    #break
        for j in range(len(named_mechList[i])):
            #print(named_mechList[i][j]['mechanism_of_action'])
            #print(named_mechList[i][j]['Protein'])
            #print(i)
            #break
            itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),BiologicalProcess(namespace='MOA',name=named_mechList[i][j]['mechanism_of_action']),citation='ChEMBL database',evidence='ChEMBL query')
            if not named_mechList[i][j]['target_chembl_id'] == None:
                #print(named_mechList[i])
                if 'Protein' in mechList_2[i][j]:
                    #print('yes')
                    itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),MicroRna(namespace='HP',name=named_mechList[i][j]['Protein']),citation='ChEMBL database',evidence='ChEMBL query')
                else:
                    itmpGraph.add_association(Pathology(namespace='ChEMBL',name=i),MicroRna(namespace='HP',name=named_mechList[i][j]['target_chembl_id']),citation='ChEMBL database',evidence='ChEMBL query')

                    
    return(itmpGraph)

# %%
test = chem2moa_rel_2(mechList_2,itmp_Graph)

# %%
from Nmr2Graph import chem2gene2path_rel
test = chem2gene2path_rel(chem2Gene_all,itmp_Graph)

# %%
chem2Gene_all['CHEMBL2842']
# Out:
# [{'xref_id': 'R-HSA-1257604',
#   'xref_name': 'PIP3 activates AKT signaling.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-1632852',
#   'xref_name': 'Macroautophagy.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-165159',
#   'xref_name': 'MTOR signalling.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-166208',
#   'xref_name': 'mTORC1-mediated signalling.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-3371571',
#   'xref_name': 'HSF1-dependent transactivation.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-380972',
#   'xref_name': 'Energy dependent regulation of mTOR by LKB1-AMPK.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-389357',
#   'xref_name': 'CD28 dependent PI3K/Akt signaling.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-5218920',
#   'xref_name': 'VEGFR2 mediated vascular permeability.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-5628897',
#   'xref_name': 'TP53 Regulates Metabolic Genes.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-5674400',
#   'xref_name': 'Constitutive Signaling by AKT1 E17K in Cancer.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-6804757',
#   'xref_name': 'Regulation of TP53 Degradation.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-8943724',
#   'xref_name': 'Regulation of PTEN gene transcription.',
#   'xref_src_db': 'Reactome'},
#  {'xref_id': 'R-HSA-9639288',
#   'xref_name': 'Amino acids regulate mTORC1.',
#   'xref_src_db': 'Reactome'},
#  {'component_synonym': 'MTOR', 'syn_type': 'GENE_SYMBOL'}]

# %%
ActList2gene2Path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\REAGON~1.KAR\AppData\Local\Temp/ipykernel_232/1132216822.py in <module>
# ----> 1 ActList2gene2Path
#
# NameError: name 'ActList2gene2Path' is not defined

# %%
test.summarize()
# Out:
# itmpGraph vNone
# Number of Nodes: 13566
# Number of Edges: 82970
# Number of Citations: 1
# Number of Authors: 0
# Network Density: 4.51E-04
# Number of Components: 30
# Number of Warnings: 0

# %%
pybel.struct.summary.count_namespaces(test)
# Out:
# Counter({'HP': 1062,
#          'ChEMBLAssay': 5045,
#          'ChEMBL': 3791,
#          'Disease': 1497,
#          'MOA': 739,
#          'Pathway': 1432})

# %%
pybel.to_graphml(test,'data/normalized_data/itmpGraph_new_2.graphml')

# %%
itmp_top51 = pd.read_excel('data/normalized_data/CHEMBL_actives_Phenotypic.xlsx',sheet_name='Pchembl>6')

# %%
itmp_top51 = list(itmp_top51['Molecule ChEMBL ID'])
#type(itmp_top51)

# %%
itmp_top51[0]
# Out:
# 'CHEMBL4303782'

# %%
nodes = [node for node in test.nodes() if node.name in itmp_top51]
to_jupyter(pybel.struct.mutation.induction.get_subgraph_by_neighborhood(test, nodes))

# %%
to_jupyter(pybel.struct.mutation.induction_expansion.get_subgraph_by_second_neighbors(test, nodes, filter_pathologies=False))

# %%
ActList2gene2Path['CHEMBL56731'][0]['ProteinName']

# %%
ActList2gene2Path

# %%
t = ActList2gene2Path['CHEMBL393929']
for i in t:
    #print(i)
    #print(i['assay_chembl_id'])
    if 'ProteinName' not in i:
        print(i)

# %%
test = chem2act_rel_2(t,itmp_Graph)
