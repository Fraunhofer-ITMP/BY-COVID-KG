# %%
pip install pyarrow
# Out:
# ...
#   Using cached pyarrow-8.0.0-cp310-cp310-win_amd64.whl (17.9 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
path = 'J:\esp\projects\ESP Projects Active\BMBF_Clusters4Future_Proxidrugs_PG_110007\GeneratedData\InnoDATA\ExperimentalData\openTargets\\targets'

# %%
test = pd.read_parquet(path+'\\'+'part-00000-bd041124-4c12-491a-80e1-2c06a071d275-c000.snappy.parquet', engine='pyarrow')

# %%
test.head(5)
# Out:
#                 id approvedSymbol               biotype  \
# 0  ENSG00000020219        CCT8L1P  processed_pseudogene
# 1  ENSG00000059588         TARBP1        protein_coding
# 2  ENSG00000070182           SPTB        protein_coding
# 3  ENSG00000070366           SMG6        protein_coding
# 4  ENSG00000072071         ADGRL1        protein_coding
#
#                                        transcriptIds  \
# 0                                  [ENST00000465400]
# 1  [ENST00000496673, ENST00000483404, ENST0000048...
# 2  [ENST00000553938, ENST00000389720, ENST0000055...
# 3  [ENST00000354901, ENST00000570756, ENST0000026...
# 4  [ENST00000361434, ENST00000589616, ENST0000059...
#
#                                      genomicLocation   alternativeGenes  \
# 0  {'chromosome': '7', 'start': 152445477, 'end':...               None
# 1  {'chromosome': '1', 'start': 234391313, 'end':...               None
# 2  {'chromosome': '14', 'start': 64746283, 'end':...               None
# ...

# %%
test['tractability'][1]
# Out:
# array([{'modality': 'SM', 'id': 'Approved Drug', 'value': False},
#        {'modality': 'SM', 'id': 'Advanced Clinical', 'value': False},
#        {'modality': 'SM', 'id': 'Phase 1 Clinical', 'value': False},
#        {'modality': 'SM', 'id': 'Structure with Ligand', 'value': True},
#        {'modality': 'SM', 'id': 'High-Quality Ligand', 'value': False},
#        {'modality': 'SM', 'id': 'High-Quality Pocket', 'value': True},
#        {'modality': 'SM', 'id': 'Med-Quality Pocket', 'value': False},
#        {'modality': 'SM', 'id': 'Druggable Family', 'value': False},
#        {'modality': 'AB', 'id': 'Approved Drug', 'value': False},
#        {'modality': 'AB', 'id': 'Advanced Clinical', 'value': False},
#        {'modality': 'AB', 'id': 'Phase 1 Clinical', 'value': False},
#        {'modality': 'AB', 'id': 'UniProt loc high conf', 'value': False},
#        {'modality': 'AB', 'id': 'GO CC high conf', 'value': False},
# ...

# %%
test['approvedIndications'][1]
# Out:
# array(['MP_0001845', 'HP_0000989', 'EFO_0000701', 'EFO_0009552',
#        'EFO_0005752'], dtype=object)

# %%
test['indications'][1]
# Out:
# array([{'disease': 'EFO_0005752', 'efoName': 'eye inflammation', 'references': array([{'source': 'ATC', 'ids': array(['S01CB03', 'S01BA02'], dtype=object)}],
#              dtype=object), 'maxPhaseForIndication': 4}                                                                                                      ,
#        {'disease': 'MONDO_0002050', 'efoName': 'depressive disorder', 'references': array([{'source': 'ClinicalTrials', 'ids': array(['NCT02837432', 'NCT04148261'], dtype=object)}],
#              dtype=object), 'maxPhaseForIndication': 0}                                                                                                                              ,
#        {'disease': 'EFO_0000701', 'efoName': 'skin disease', 'references': array([{'source': 'DailyMed', 'ids': array(['e86a5293-312d-4425-bf95-35e4d7149aed',
#                      '1eb217be-34f1-4b3b-a3a5-4dfb83fb6143',
# ...
